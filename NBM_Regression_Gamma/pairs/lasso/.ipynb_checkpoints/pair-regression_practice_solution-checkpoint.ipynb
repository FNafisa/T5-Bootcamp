# %%
# !pwd
# Out:
# /Users/jeddy-metis/Documents/git/nyc20_ds24/pairs/lasso

# %% [markdown]
# #### Pair Problem - Week2 - Day5 - Regression Practice
#
# Practice Lasso regularization technique in five steps:
#
# 1) Load Diabetes Dataset from SK Learn (`sklearn.datasets.load_diabetes()`).  Note that data may already be normalized.
#
# 2) Using sklearn model selection's `train_test_split`, hold out a portion of the data for final testing.
#
# 3) Use the KFold function from sklearn's cross validation module to divide the non-test data into 5 training/validation sets.  Randomize the KFold (via the shuffle parameter with Random State of 0).
#
# 4) Tune the lambda (alpha) parameter in the lasso model by looping over a grid of possible lambdas (sklearn: lasso)
# and scoring each value on each validation fold.
#
# ```
# For each candidate lambda, loop over the 5 training/validation sets.
# On each training/test set run the lasso model on the training set and then compute and record the prediction error in the validation set.
# Finally total the prediction error for the 5 training/validation sets.
# ```
#
# 5) Set lambda to be the value that minimizes prediction error across the validation folds.
#
# 6) Run the lasso model again on the entire train+validation data with the optimal lambda determined in step 3.
# Which variables would you consider excluding on the basis of these results?
#
# 7) Try with Ridge and ElasticNet and base LinearRegression Models.  Compare your results.
#
# Once you've selected what you think is the best model, train it on train+validation, predict on your held out test data,
# and report the final result.
#
# **Extra Credit**:  Try some Feature Engineering (Polynomials etc) to fit the data better.  Plot the data to see relationships.

# %%
from __future__ import division, print_function  # Python 2 and 3 Compatibility

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %matplotlib inline

# %%
from sklearn.datasets import load_diabetes
from sklearn.linear_model import Lasso, Ridge, ElasticNet, LinearRegression

from sklearn.model_selection import (cross_val_score, train_test_split, 
                                     KFold, GridSearchCV)

# %% [markdown]
# ### Load Data

# %%
diabetes = load_diabetes()

# %%
diabetes.keys()
# Out:
# dict_keys(['data', 'target', 'DESCR', 'feature_names', 'data_filename', 'target_filename'])

# %% [markdown]
# * data Matrix is X and target vector is y

# %%
diabetes.data.shape
# Out:
# (442, 10)

# %% [markdown]
# ### Build a Hold Out Set to test different Models

# %%
X_train, X_holdout, y_train, y_holdout = train_test_split(diabetes.data, diabetes.target, test_size=0.1, random_state=42)

# %% [markdown]
# ### Split Training Data into Multiple Folds

# %%
# Notice that we are splitting the X_train data into 5 Folds

kfold = KFold(n_splits=5, shuffle=True, random_state=0)

# %% [markdown]
# ### Baseline: Linear Regression

# %%
lin_reg_est = LinearRegression()

scores = cross_val_score(lin_reg_est, X_train, y_train, cv=kfold)
print(scores)
print("Linear Reg Mean Score: ", np.mean(scores))

# Build the Model
lin_reg_est.fit(X_train, y_train)
# Out:
# [0.38015962 0.41985738 0.55536535 0.48203479 0.52900323]
# Linear Reg Mean Score:  0.47328407543781364
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %% [markdown]
# ### Evaluating Model

# %%
# Fitted vs. Actual
y_train_pred = lin_reg_est.predict(X_train)

plt.scatter(y_train, y_train_pred, alpha=0.2)
plt.plot([0, 400], [0, 400])

# %%
# Fitted vs. Actual
y_test_pred = lin_reg_est.predict(X_holdout)

plt.scatter(y_holdout, y_test_pred)
plt.plot([0, 400], [0, 400])

# %%
# Plot Residuals vs. predicted

lin_reg_residuals = y_train - y_train_pred

plt.scatter(y_train_pred, lin_reg_residuals)
plt.plot([0,400], [0, 0])
plt.title("Residuals vs. Predictions")

# %% [markdown]
# ### Lasso

# %%
print("Lasso Model:")
params = {
    "alpha": np.logspace(-4, -.1, 20)
}

grid_est = GridSearchCV(Lasso(), param_grid=params, cv=kfold, 
                        return_train_score=False)
grid_est.fit(X_train, y_train)
df = pd.DataFrame(grid_est.cv_results_)
df["alpha"] = df.params.apply(lambda val: val["alpha"])
plt.plot(np.log(df.alpha), df.mean_test_score);
# Out:
# Lasso Model:

# %%
grid_est.best_estimator_
# Out:
# Lasso(alpha=0.004386370005779536, copy_X=True, fit_intercept=True,
#       max_iter=1000, normalize=False, positive=False, precompute=False,
#       random_state=None, selection='cyclic', tol=0.0001, warm_start=False)

# %%
params['alpha']
# Out:
# array([1.00000000e-04, 1.60421716e-04, 2.57351270e-04, 4.12847324e-04,
#        6.62296762e-04, 1.06246783e-03, 1.70442913e-03, 2.73427446e-03,
#        4.38637001e-03, 7.03669004e-03, 1.12883789e-02, 1.81090112e-02,
#        2.90507865e-02, 4.66037703e-02, 7.47625680e-02, 1.19935395e-01,
#        1.92402418e-01, 3.08655261e-01, 4.95150067e-01, 7.94328235e-01])

# %% [markdown]
# ### Ridge

# %%
print("Ridge Model:")
params = {
    "alpha": np.logspace(-4, -.1, 20)
}

grid_est = GridSearchCV(Ridge(), param_grid=params, cv=kfold, 
                        return_train_score=False)
grid_est.fit(X_train, y_train)
df = pd.DataFrame(grid_est.cv_results_)
df["alpha"] = df.params.apply(lambda val: val["alpha"])
plt.plot(np.log(df.alpha), df.mean_test_score);
# Out:
# Ridge Model:

# %% [markdown]
# ### Make Functions for repeatable Code - DRY

# %%
def build_grid_search_est(model, X, y, cv=5, **params):

    grid_est = GridSearchCV(model, param_grid=params, cv=kfold, 
                            return_train_score=False)
    grid_est.fit(X, y)
    df = pd.DataFrame(grid_est.cv_results_)
    for param in params:
        df[param] = df.params.apply(lambda val: val[param])
#       plt.plot(np.log(df.alpha), df.mean_test_score);
        plt.semilogx(df.alpha, df.mean_test_score)
    return grid_est

# %%
print("Lasso Grid Search")
lasso_grid_est = build_grid_search_est(Lasso(), X_train, y_train, cv=kfold,
                                       alpha=np.logspace(-4, -1, 30))
# Out:
# Lasso Grid Search

# %%
print("Ridge Grid Search")
ridge_grid_est = build_grid_search_est(Ridge(), X_train, y_train, cv=kfold,
                                       alpha=np.logspace(-4, -1, 10))
# Out:
# Ridge Grid Search

# %%
print("Elastic Net Grid Search")
elastic_net_grid_est = build_grid_search_est(ElasticNet(), X_train, y_train, cv=kfold,
                                             alpha=np.logspace(-4, 0.1, 30),
                                             l1_ratio=np.linspace(0,1,30,endpoint=False))
# Out:
# Elastic Net Grid Search
# /anaconda3/lib/python3.6/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 482321.48857576464, tolerance: 198.47250347003154
#   positive)
# /anaconda3/lib/python3.6/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 469803.76920243434, tolerance: 192.02449526813882
#   positive)
# /anaconda3/lib/python3.6/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 470701.4931502756, tolerance: 181.29824685534592
#   positive)
# /anaconda3/lib/python3.6/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 453687.95387219795, tolerance: 182.30611698113208
#   positive)
# /anaconda3/lib/python3.6/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 471098.9224709992, tolerance: 183.7096783018868
#   positive)
# /anaconda3/lib/python3.6/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 486998.88050733303, tolerance: 198.47250347003154
#   positive)
# /anaconda3/lib/python3.6/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 474346.0721656958, tolerance: 192.02449526813882
#   positive)
# /anaconda3/lib/python3.6/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 474642.7689668667, tolerance: 181.29824685534592
#   positive)
# /anaconda3/lib/python3.6/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 457724.5165887856, tolerance: 182.30611698113208
#   positive)
# /anaconda3/lib/python3.6/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 475464.1339598418, tolerance: 183.7096783018868
#   positive)
# /anaconda3/lib/python3.6/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 493153.5998224015, tolerance: 198.47250347003154
#   positive)
# /anaconda3/lib/python3.6/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 480327.10551656794, tolerance: 192.02449526813882
#   positive)
# /anaconda3/lib/python3.6/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 479867.95275927393, tolerance: 181.29824685534592
#   positive)
# /anaconda3/lib/python3.6/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 463082.02640300145, tolerance: 182.30611698113208
#   positive)
# /anaconda3/lib/python3.6/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 481174.1530318031, tolerance: 183.7096783018868
#   positive)
# /anaconda3/lib/python3.6/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 501220.6256669498, tolerance: 198.47250347003154
#   positive)
# /anaconda3/lib/python3.6/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 488183.17625735514, tolerance: 192.02449526813882
#   positive)
# /anaconda3/lib/python3.6/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 486761.7162360678, tolerance: 181.29824685534592
#   positive)
# /anaconda3/lib/python3.6/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 470154.73096248525, tolerance: 182.30611698113208
#   positive)
# /anaconda3/lib/python3.6/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 488624.92127727467, tolerance: 183.7096783018868
#   positive)
# /anaconda3/lib/python3.6/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 511700.0272350751, tolerance: 198.47250347003154
#   positive)
# /anaconda3/lib/python3.6/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 498415.29072140926, tolerance: 192.02449526813882
#   positive)
# /anaconda3/lib/python3.6/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 495767.88493561954, tolerance: 181.29824685534592
#   positive)
# /anaconda3/lib/python3.6/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 479397.6542287628, tolerance: 182.30611698113208
#   positive)
# /anaconda3/lib/python3.6/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 498261.61622431024, tolerance: 183.7096783018868
#   positive)
# /anaconda3/lib/python3.6/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 525126.7519165981, tolerance: 198.47250347003154
#   positive)
# /anaconda3/lib/python3.6/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 511556.61930238636, tolerance: 192.02449526813882
#   positive)
# /anaconda3/lib/python3.6/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 507362.8739982366, tolerance: 181.29824685534592
#   positive)
# /anaconda3/lib/python3.6/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 491300.284889148, tolerance: 182.30611698113208
#   positive)
# /anaconda3/lib/python3.6/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 510544.7040114092, tolerance: 183.7096783018868
#   positive)
# /anaconda3/lib/python3.6/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 542015.0646244294, tolerance: 198.47250347003154
#   positive)
# /anaconda3/lib/python3.6/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 528113.2093635056, tolerance: 192.02449526813882
#   positive)
# /anaconda3/lib/python3.6/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 522005.5572327758, tolerance: 181.29824685534592
#   positive)
# /anaconda3/lib/python3.6/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 506337.5020912435, tolerance: 182.30611698113208
#   positive)
# /anaconda3/lib/python3.6/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 525894.5814097321, tolerance: 183.7096783018868
#   positive)
# /anaconda3/lib/python3.6/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 562778.2222950291, tolerance: 198.47250347003154
#   positive)
# /anaconda3/lib/python3.6/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 548478.6556465654, tolerance: 192.02449526813882
#   positive)
# /anaconda3/lib/python3.6/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 540063.0811462065, tolerance: 181.29824685534592
#   positive)
# /anaconda3/lib/python3.6/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 524897.7880398154, tolerance: 182.30611698113208
#   positive)
# /anaconda3/lib/python3.6/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 544619.1437829108, tolerance: 183.7096783018868
#   positive)
# /anaconda3/lib/python3.6/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 587634.8849505568, tolerance: 198.47250347003154
#   positive)
# /anaconda3/lib/python3.6/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 572836.2738645702, tolerance: 192.02449526813882
#   positive)
# /anaconda3/lib/python3.6/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 561722.5398079874, tolerance: 181.29824685534592
#   positive)
# /anaconda3/lib/python3.6/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 547198.2420012256, tolerance: 182.30611698113208
#   positive)
# /anaconda3/lib/python3.6/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 566838.9306464121, tolerance: 183.7096783018868
#   positive)
# /anaconda3/lib/python3.6/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 616524.1984565535, tolerance: 198.47250347003154
#   positive)
# /anaconda3/lib/python3.6/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 601075.1210285822, tolerance: 192.02449526813882
#   positive)
# /anaconda3/lib/python3.6/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 586909.8122712572, tolerance: 181.29824685534592
#   positive)
# /anaconda3/lib/python3.6/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 573205.0953888973, tolerance: 182.30611698113208
#   positive)
# /anaconda3/lib/python3.6/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 592430.9352659098, tolerance: 183.7096783018868
#   positive)
# /anaconda3/lib/python3.6/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 649053.1463613263, tolerance: 198.47250347003154
#   positive)
# /anaconda3/lib/python3.6/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 632747.7671155465, tolerance: 192.02449526813882
#   positive)
# /anaconda3/lib/python3.6/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 615240.7022772853, tolerance: 181.29824685534592
#   positive)
# /anaconda3/lib/python3.6/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 602580.0415232452, tolerance: 182.30611698113208
#   positive)
# /anaconda3/lib/python3.6/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 621006.5898263697, tolerance: 183.7096783018868
#   positive)
# /anaconda3/lib/python3.6/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 684488.457587939, tolerance: 198.47250347003154
#   positive)
# /anaconda3/lib/python3.6/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 667081.584150194, tolerance: 192.02449526813882
#   positive)
# /anaconda3/lib/python3.6/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 646019.5728843678, tolerance: 181.29824685534592
#   positive)
# /anaconda3/lib/python3.6/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 634663.7839885314, tolerance: 182.30611698113208
#   positive)
# /anaconda3/lib/python3.6/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 651922.4722008355, tolerance: 183.7096783018868
#   positive)
# /anaconda3/lib/python3.6/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 721789.9474097582, tolerance: 198.47250347003154
#   positive)
# /anaconda3/lib/python3.6/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 703032.7804473476, tolerance: 192.02449526813882
#   positive)
# /anaconda3/lib/python3.6/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 678283.3662166516, tolerance: 181.29824685534592
#   positive)
# /anaconda3/lib/python3.6/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 668497.5914696724, tolerance: 182.30611698113208
#   positive)
# /anaconda3/lib/python3.6/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 684309.5612100462, tolerance: 183.7096783018868
#   positive)
# /anaconda3/lib/python3.6/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 759679.628558555, tolerance: 198.47250347003154
#   positive)
# /anaconda3/lib/python3.6/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 739366.61441752, tolerance: 192.02449526813882
#   positive)
# /anaconda3/lib/python3.6/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 710881.056123411, tolerance: 181.29824685534592
#   positive)
# /anaconda3/lib/python3.6/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 702884.6542695822, tolerance: 182.30611698113208
#   positive)
# /anaconda3/lib/python3.6/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 717115.5573147618, tolerance: 183.7096783018868
#   positive)
# /anaconda3/lib/python3.6/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 796752.9175851409, tolerance: 198.47250347003154
#   positive)
# /anaconda3/lib/python3.6/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 774763.2738262847, tolerance: 192.02449526813882
#   positive)
# /anaconda3/lib/python3.6/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 742585.5421092621, tolerance: 181.29824685534592
#   positive)
# /anaconda3/lib/python3.6/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 736502.0184476716, tolerance: 182.30611698113208
#   positive)
# /anaconda3/lib/python3.6/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 749177.4376205497, tolerance: 183.7096783018868
#   positive)
# /anaconda3/lib/python3.6/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 831639.8357563884, tolerance: 198.47250347003154
#   positive)
# /anaconda3/lib/python3.6/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 807959.0497667626, tolerance: 192.02449526813882
#   positive)
# /anaconda3/lib/python3.6/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 772237.5284248494, tolerance: 181.29824685534592
#   positive)
# /anaconda3/lib/python3.6/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 768066.5215624503, tolerance: 182.30611698113208
#   positive)
# /anaconda3/lib/python3.6/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 779344.9752133966, tolerance: 183.7096783018868
#   positive)
# /anaconda3/lib/python3.6/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 863194.8807308505, tolerance: 198.47250347003154
#   positive)
# /anaconda3/lib/python3.6/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 837910.482433684, tolerance: 192.02449526813882
#   positive)
# /anaconda3/lib/python3.6/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 798900.9538298871, tolerance: 181.29824685534592
#   positive)
# /anaconda3/lib/python3.6/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 796523.4660219144, tolerance: 182.30611698113208
#   positive)
# /anaconda3/lib/python3.6/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 806642.1685654041, tolerance: 183.7096783018868
#   positive)
# /anaconda3/lib/python3.6/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 890656.4311506385, tolerance: 198.47250347003154
#   positive)
# /anaconda3/lib/python3.6/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 863933.0440387944, tolerance: 192.02449526813882
#   positive)
# /anaconda3/lib/python3.6/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 821983.4131239606, tolerance: 181.29824685534592
#   positive)
# /anaconda3/lib/python3.6/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 821194.2995689258, tolerance: 182.30611698113208
#   positive)
# /anaconda3/lib/python3.6/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 830411.2499050699, tolerance: 183.7096783018868
#   positive)
# /anaconda3/lib/python3.6/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 913714.870870022, tolerance: 198.47250347003154
#   positive)
# /anaconda3/lib/python3.6/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 885760.0049248522, tolerance: 192.02449526813882
#   positive)
# /anaconda3/lib/python3.6/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 841277.3061754016, tolerance: 181.29824685534592
#   positive)
# /anaconda3/lib/python3.6/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 841828.4764569186, tolerance: 182.30611698113208
#   positive)
# /anaconda3/lib/python3.6/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 850379.5241960378, tolerance: 183.7096783018868
#   positive)
# /anaconda3/lib/python3.6/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 932472.0833853183, tolerance: 198.47250347003154
#   positive)
# /anaconda3/lib/python3.6/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 903503.978965928, tolerance: 192.02449526813882
#   positive)
# /anaconda3/lib/python3.6/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 856913.542891794, tolerance: 181.29824685534592
#   positive)
# /anaconda3/lib/python3.6/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 858552.3358015504, tolerance: 182.30611698113208
#   positive)
# /anaconda3/lib/python3.6/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 866629.6945567298, tolerance: 183.7096783018868
#   positive)
# /anaconda3/lib/python3.6/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 947325.761039304, tolerance: 198.47250347003154
#   positive)
# /anaconda3/lib/python3.6/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 917549.9685815887, tolerance: 192.02449526813882
#   positive)
# /anaconda3/lib/python3.6/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 869258.6553399883, tolerance: 181.29824685534592
#   positive)
# /anaconda3/lib/python3.6/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 871753.5815415574, tolerance: 182.30611698113208
#   positive)
# /anaconda3/lib/python3.6/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 879501.9890897844, tolerance: 183.7096783018868
#   positive)
# /anaconda3/lib/python3.6/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 958832.6540794718, tolerance: 198.47250347003154
#   positive)
# /anaconda3/lib/python3.6/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 928428.8269465028, tolerance: 192.02449526813882
#   positive)
# /anaconda3/lib/python3.6/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 878799.8080666016, tolerance: 181.29824685534592
#   positive)
# /anaconda3/lib/python3.6/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 881953.266195828, tolerance: 182.30611698113208
#   positive)
# /anaconda3/lib/python3.6/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 889476.0901655671, tolerance: 183.7096783018868
#   positive)
# /anaconda3/lib/python3.6/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 967592.8055141757, tolerance: 198.47250347003154
#   positive)
# /anaconda3/lib/python3.6/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 936709.8773540972, tolerance: 192.02449526813882
#   positive)
# /anaconda3/lib/python3.6/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 886050.408519183, tolerance: 181.29824685534592
#   positive)
# /anaconda3/lib/python3.6/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 889701.773859085, tolerance: 182.30611698113208
#   positive)
# /anaconda3/lib/python3.6/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 897070.4692688613, tolerance: 183.7096783018868
#   positive)
# /anaconda3/lib/python3.6/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 974172.3863192834, tolerance: 198.47250347003154
#   positive)
# /anaconda3/lib/python3.6/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 942929.2163953129, tolerance: 192.02449526813882
#   positive)
# /anaconda3/lib/python3.6/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 891488.8125979023, tolerance: 181.29824685534592
#   positive)
# /anaconda3/lib/python3.6/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 895511.9138218246, tolerance: 182.30611698113208
#   positive)
# /anaconda3/lib/python3.6/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 902775.0481801966, tolerance: 183.7096783018868
#   positive)
# /anaconda3/lib/python3.6/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 979063.6377242492, tolerance: 198.47250347003154
#   positive)
# /anaconda3/lib/python3.6/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 947552.5075241565, tolerance: 192.02449526813882
#   positive)
# /anaconda3/lib/python3.6/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 895527.6245445316, tolerance: 181.29824685534592
#   positive)
# /anaconda3/lib/python3.6/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 899825.7183775669, tolerance: 182.30611698113208
#   positive)
# /anaconda3/lib/python3.6/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 907016.1249892476, tolerance: 183.7096783018868
#   positive)
# /anaconda3/lib/python3.6/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 982671.8359295332, tolerance: 198.47250347003154
#   positive)
# /anaconda3/lib/python3.6/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 950962.9753557914, tolerance: 192.02449526813882
#   positive)
# /anaconda3/lib/python3.6/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 898504.7616356919, tolerance: 181.29824685534592
#   positive)
# /anaconda3/lib/python3.6/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 903004.927031255, tolerance: 182.30611698113208
#   positive)
# /anaconda3/lib/python3.6/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 910144.8532244416, tolerance: 183.7096783018868
#   positive)
# /anaconda3/lib/python3.6/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 985318.330656486, tolerance: 198.47250347003154
#   positive)
# /anaconda3/lib/python3.6/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 953464.418741661, tolerance: 192.02449526813882
#   positive)
# /anaconda3/lib/python3.6/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 900687.1923326473, tolerance: 181.29824685534592
#   positive)
# /anaconda3/lib/python3.6/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 905335.1285784928, tolerance: 182.30611698113208
#   positive)
# /anaconda3/lib/python3.6/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 912439.7509148883, tolerance: 183.7096783018868
#   positive)
# /anaconda3/lib/python3.6/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 987251.2605945213, tolerance: 198.47250347003154
#   positive)
# /anaconda3/lib/python3.6/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 955291.3987653392, tolerance: 192.02449526813882
#   positive)
# /anaconda3/lib/python3.6/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 902280.5405600229, tolerance: 181.29824685534592
#   positive)
# /anaconda3/lib/python3.6/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 907036.1615370191, tolerance: 182.30611698113208
#   positive)
# /anaconda3/lib/python3.6/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 914115.9238296049, tolerance: 183.7096783018868
#   positive)
# /anaconda3/lib/python3.6/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 988658.6540323878, tolerance: 198.47250347003154
#   positive)
# /anaconda3/lib/python3.6/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 956621.6456844799, tolerance: 192.02449526813882
#   positive)
# /anaconda3/lib/python3.6/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 903440.3393868336, tolerance: 181.29824685534592
#   positive)
# /anaconda3/lib/python3.6/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 908274.2353383966, tolerance: 182.30611698113208
#   positive)
# /anaconda3/lib/python3.6/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 915336.3895224615, tolerance: 183.7096783018868
#   positive)
# /anaconda3/lib/python3.6/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 989681.0814052066, tolerance: 198.47250347003154
#   positive)
# /anaconda3/lib/python3.6/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 957588.0275545123, tolerance: 192.02449526813882
#   positive)
# /anaconda3/lib/python3.6/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 904282.7172601917, tolerance: 181.29824685534592
#   positive)
# /anaconda3/lib/python3.6/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 909173.4068881472, tolerance: 182.30611698113208
#   positive)
# /anaconda3/lib/python3.6/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 916223.0303730995, tolerance: 183.7096783018868
#   positive)

# %% [markdown]
# ### Evaluating Models using Holdout Set across these four models

# %%
from sklearn.metrics import r2_score, mean_squared_error

y_pred = lin_reg_est.predict(X_holdout)
print("Linear Regression:", r2_score(y_holdout, y_pred))

y_pred = lasso_grid_est.predict(X_holdout)
print("Lasso Regression:", r2_score(y_holdout, y_pred))

y_pred = ridge_grid_est.predict(X_holdout)
print("Ridge Regression:", r2_score(y_holdout, y_pred))

y_pred = elastic_net_grid_est.predict(X_holdout)
print("ElasticNet Regression:", r2_score(y_holdout, y_pred))
# Out:
# Linear Regression: 0.5514251914993505
# Lasso Regression: 0.5538976451040124
# Ridge Regression: 0.5519730779435753
# ElasticNet Regression: 0.5509086912057095

# %%
pd.DataFrame(list(zip(range(10), lasso_grid_est.best_estimator_.coef_)))
# Out:
#    0           1
# 0  0   17.668205
# 1  1 -256.342212
# 2  2  512.816072
# 3  3  332.674929
# 4  4 -567.943028
# 5  5  259.323008
# 6  6   -0.000000
# 7  7  198.935809
# 8  8  613.988716
# 9  9   70.051069

# %% [markdown]
# ### EDA

# %%
diabetes_df = pd.DataFrame(diabetes.data)
diabetes_df.columns = ["X" + str(col) for col in diabetes_df.columns]
diabetes_df["target"] = diabetes.target

# %%
diabetes_df.corr()
# Out:
#               X0        X1        X2        X3        X4        X5        X6  \
# X0      1.000000  0.173737  0.185085  0.335427  0.260061  0.219243 -0.075181
# X1      0.173737  1.000000  0.088161  0.241013  0.035277  0.142637 -0.379090
# X2      0.185085  0.088161  1.000000  0.395415  0.249777  0.261170 -0.366811
# X3      0.335427  0.241013  0.395415  1.000000  0.242470  0.185558 -0.178761
# X4      0.260061  0.035277  0.249777  0.242470  1.000000  0.896663  0.051519
# X5      0.219243  0.142637  0.261170  0.185558  0.896663  1.000000 -0.196455
# X6     -0.075181 -0.379090 -0.366811 -0.178761  0.051519 -0.196455  1.000000
# X7      0.203841  0.332115  0.413807  0.257653  0.542207  0.659817 -0.738493
# X8      0.270777  0.149918  0.446159  0.393478  0.515501  0.318353 -0.398577
# X9      0.301731  0.208133  0.388680  0.390429  0.325717  0.290600 -0.273697
# target  0.187889  0.043062  0.586450  0.441484  0.212022  0.174054 -0.394789
#
#               X7        X8        X9    target
# X0      0.203841  0.270777  0.301731  0.187889
# X1      0.332115  0.149918  0.208133  0.043062
# X2      0.413807  0.446159  0.388680  0.586450
# X3      0.257653  0.393478  0.390429  0.441484
# X4      0.542207  0.515501  0.325717  0.212022
# X5      0.659817  0.318353  0.290600  0.174054
# X6     -0.738493 -0.398577 -0.273697 -0.394789
# X7      1.000000  0.617857  0.417212  0.430453
# X8      0.617857  1.000000  0.464670  0.565883
# X9      0.417212  0.464670  1.000000  0.382483
# target  0.430453  0.565883  0.382483  1.000000

# %%
sns.pairplot(diabetes_df)

# %% [markdown]
# ## Other Models

# %%
from sklearn.preprocessing import PolynomialFeatures

poly = PolynomialFeatures()

lm_poly = LinearRegression()
lm_poly.fit(poly.fit_transform(X_train), y_train)
y_pred = lm_poly.predict(poly.transform(X_holdout))
print("Polynomial Regression:", r2_score(y_holdout, y_pred))
# Out:
# Polynomial Regression: 0.4677993429299774

# %% [markdown]
# Yikes!!

# %%
#getting fancy - we can do at least a little bit better
#(I should have cross-validated these to be rigorous)
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor

rf = RandomForestRegressor(n_estimators=2000, max_features=3, max_depth=5)
rf.fit(X_train, y_train)
y_pred = rf.predict(X_holdout)
print("Random Forest Regression:", r2_score(y_holdout, y_pred))

gbm = GradientBoostingRegressor(n_estimators=500, max_depth=3, learning_rate=.01)
gbm.fit(X_train, y_train)
y_pred = gbm.predict(X_holdout)
print("Gradient Boosted Regression:", r2_score(y_holdout, y_pred))
# Out:
# Random Forest Regression: 0.5686274428493127
# Gradient Boosted Regression: 0.6030163498872996

# %% [markdown]
# That's more like it.

# %%
sns.jointplot(y_pred, y_holdout, kind='regplot')

# %%
sns.jointplot(y_pred, y_holdout - y_pred, kind='regplot')
