# %% [markdown]
# # Web Scraping: Selenium
# _Automate your browser._ <br>
# _Collect data from dynamically generated web pages or those requiring user interaction._
#
# ### Docs
#
# - [Selenium homepage](https://www.seleniumhq.org/)
# - [Selenium documentation](https://selenium-python.readthedocs.io/) - unofficial, but helpful
#
# ### Installation
#
# With conda:
# - `conda install -c conda-forge selenium`
#
# With pip:
# - `pip install -U selenium`
#
# #### ChromeDriver
#
# You will also need to install a web driver to use Selenium.  ChromeDriver is recommended but others are also available.
#
# 1. Check your browser's version _(Chrome > About Google Chrome)_
# ![Browser Version](images/browser_version.png)
# <br>
# 2. Navigate to the [ChromeDriver downloads page](https://sites.google.com/a/chromium.org/chromedriver/downloads).
# <br><br>
# 3. Download appropriately based on your browser's version and your OS.
# ![Download ChromeDriver zip file](images/chromedriver_options.png)
#
# 4. Unzip the driver.
# <br><br>
# 5. Move to Applications folder (or wherever your Chrome application is).

# %%
ls
# Out:
#  Volume in drive C is Windows
#  Volume Serial Number is A020-D39D
#
#  Directory of C:\Users\fahadd\t5_bootcamp_directory\PRACTICE\gamma\NBM_Regression_Gamma
#
# 11/22/2021  11:12 AM    <DIR>          .
# 11/22/2021  11:12 AM    <DIR>          ..
# 11/21/2021  09:54 AM    <DIR>          careers
# 11/22/2021  11:08 AM    <DIR>          chromedriver_win32
# 11/21/2021  09:54 AM    <DIR>          curriculum
# 11/21/2021  09:54 AM    <DIR>          pairs
# 11/21/2021  09:54 AM             9,690 README.md
# 11/21/2021  09:54 AM    <DIR>          resources
#                1 File(s)          9,690 bytes
#                7 Dir(s)  693,355,278,336 bytes free

# %%
from bs4 import BeautifulSoup
import requests
import time, os

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys

# driver= webdriver.Chrome(ChromeDriverManager().install())


chromedriver = "chromedriver_win32/chromedriver.exe" # path to the chromedriver executable
os.environ["webdriver.chrome.driver"] = chromedriver

# %% [markdown]
# ## Example 1 - YouTube
#
# ### Dynamic Pages
#
# Some pages serve their content dynamically, which means they could look different each time they are loaded into the browser.  HTML that you see by inspecting elements in your browser might be missing from `requests` and `BeautifulSoup` because it is generated at access time.

# %%
# query = "data science"
youtube_search = "https://www.youtube.com"
# youtube_query = youtube_search + query.replace(' ', '+')
page = requests.get(youtube_search).text

soup = BeautifulSoup(page, 'html5lib')
print(soup.find('div'))
# Out:
# <div class="ytd-searchbox-spt" id="search-container" slot="search-container"></div>

# %%
query = "data science"
youtube_search = "https://www.youtube.com/results?search_query="
youtube_query = youtube_search + query.replace(' ', '+')

# %%
page = requests.get(youtube_query).text

soup = BeautifulSoup(page, 'html5lib')

# %%
soup.find('div', id='contents')

# %% [markdown]
# Uh oh.  The video links should be under the contents div, but it's missing from our request.
#
# > **QUESTION**: Why do you think this happened?

# %% [markdown]
# One option is to first load the page with Selenium THEN parse the page's HTML with BeautifulSoup.
#
# First we launch the YouTube search page through our ChromeDrive.  A new browser should pop up.  **To continue using Selenium, keep this window open!**

# %%
driver = webdriver.Chrome(chromedriver)
driver.get(youtube_query)
# Out:
# C:\Users\fahadd\AppData\Local\Temp/ipykernel_12560/3870637114.py:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(chromedriver)

# %% [markdown]
# We can access the page's HTML through the driver:

# %%
driver.page_source[:1000]

# %% [markdown]
# Now we parse this with `BeautifulSoup` and the video information appears!

# %%
soup = BeautifulSoup(driver.page_source, 'html.parser')

# %%
soup.find('div', id='contents')
# Out:
# <div class="style-scope ytd-section-list-renderer" id="contents"><ytd-item-section-renderer class="style-scope ytd-section-list-renderer" use-height-hack=""><!--css-build:shady--><div class="style-scope ytd-item-section-renderer" id="header"></div>
# <div class="style-scope ytd-item-section-renderer" id="spinner-container">
# <tp-yt-paper-spinner-lite aria-hidden="true" class="style-scope ytd-item-section-renderer"><!--css-build:shady--><div class="style-scope tp-yt-paper-spinner-lite" id="spinnerContainer"><div class="spinner-layer style-scope tp-yt-paper-spinner-lite"><div class="circle-clipper left style-scope tp-yt-paper-spinner-lite"><div class="circle style-scope tp-yt-paper-spinner-lite"></div></div><div class="circle-clipper right style-scope tp-yt-paper-spinner-lite"><div class="circle style-scope tp-yt-paper-spinner-lite"></div></div></div></div></tp-yt-paper-spinner-lite>
# </div>
# <div class="style-scope ytd-item-section-renderer" id="contents"><ytd-promoted-sparkles-web-renderer class="style-scope ytd-item-section-renderer sparkles-light-cta" hide-hover-overlay="" web-search-layout="" web-search-layout-square=""><!--css-build:shady--><div class="style-scope ytd-promoted-sparkles-web-renderer" id="sparkles-container">
# <div class="style-scope ytd-promoted-sparkles-web-renderer" id="thumbnail-container">
# <div class="style-scope ytd-promoted-sparkles-web-renderer" id="thumbnail-deep-container">
# <yt-img-shadow class="style-scope ytd-promoted-sparkles-web-renderer no-transition" id="thumbnail" loaded="" object-fit="CONTAIN" style="background-color: transparent;"><!--css-build:shady--><img alt="" class="style-scope yt-img-shadow" id="img" src="https://tpc.googlesyndication.com/simgad/7870558498575716014"/></yt-img-shadow>
# <div class="style-scope ytd-promoted-sparkles-web-renderer" id="media-badge-search"><ytd-badge-supported-renderer class="style-scope ytd-promoted-sparkles-web-renderer" system-icons=""><!--css-build:shady-->
# <div class="badge badge-style-type-black style-scope ytd-badge-supported-renderer">
# <yt-icon class="style-scope ytd-badge-supported-renderer"><svg class="style-scope yt-icon" focusable="false" preserveaspectratio="xMidYMid meet" style="pointer-events: none; display: block; width: 100%; height: 100%;" viewbox="0 0 24 24"><g class="style-scope yt-icon"><path class="style-scope yt-icon" d="M21,21H3V3h9v1H4v16h16v-8h1V21z M15,3v1h4.32l-8.03,8.03L12,12.74l8-8V9h1V3H15z"></path></g></svg><!--css-build:shady--></yt-icon>
# <span class="style-scope ytd-badge-supported-renderer"></span>
# </div>
# <dom-repeat as="badge" class="style-scope ytd-badge-supported-renderer" id="repeat"><template is="dom-repeat"></template></dom-repeat>
# </ytd-badge-supported-renderer></div>
# <div class="style-scope ytd-promoted-sparkles-web-renderer" id="media-hover-overlay-search"></div>
# </div>
# <div class="style-scope ytd-promoted-sparkles-web-renderer" id="media-hover-overlay"></div>
# </div>
# <div class="style-scope ytd-promoted-sparkles-web-renderer" id="sparkles-body">
# <h3 class="style-scope ytd-promoted-sparkles-web-renderer" id="title" title="How To Leverage Data Science - Dataiku: Everyday AI">
#         How To Leverage Data Science - Dataiku: Everyday AI
#     </h3>
# <div class="style-scope ytd-promoted-sparkles-web-renderer" id="description">
#       Get The eBook &amp; Discover The Benefits Of Accelerating AI Maturity In Your Organization. Get The eBook To Learn How To Get Value Out Of Data &amp; Move Your Organization Forward. Enterprise AI.
#     </div>
# <div class="style-scope ytd-promoted-sparkles-web-renderer" id="website-text-container">
# <ytd-badge-supported-renderer class="style-scope ytd-promoted-sparkles-web-renderer" id="ad-badge" system-icons=""><!--css-build:shady-->
# <div class="badge badge-style-type-ad style-scope ytd-badge-supported-renderer">
# <yt-icon class="style-scope ytd-badge-supported-renderer" disable-upgrade="" hidden="">
# </yt-icon>
# <span class="style-scope ytd-badge-supported-renderer">Ad</span>
# </div>
# <dom-repeat as="badge" class="style-scope ytd-badge-supported-renderer" id="repeat"><template is="dom-repeat"></template></dom-repeat>
# </ytd-badge-supported-renderer>
# <div class="style-scope ytd-promoted-sparkles-web-renderer" id="website-text">
#         https://pages.dataiku.com/
#       </div>
# </div>
# <div class="style-scope ytd-promoted-sparkles-web-renderer" id="action-button"><ytd-button-renderer button-renderer="true" class="style-scope ytd-promoted-sparkles-web-renderer style-suggestive" is-paper-button="" is-paper-button-with-icon="" use-keyboard-focused=""><a class="yt-simple-endpoint style-scope ytd-button-renderer" href="https://www.google.com/aclk?sa=l&amp;ai=CJYBlRHCbYbC-OMi11gbn_LbICquIy7hm5PWX68sOjfetqwkIABABILubuk4oAmCrzfOF8B6gAZmO2eoCyAEBqgRTT9DSI6B1HBGRf5TLE8ggO22-8_WtUPjUqrc4h68VFU2A2vI_d-sQDe0uLZghFxViso_kOtldRvHNNcQZvjgzmJsEUE2P4IqUKPE4tasYBX8fwvjABOuv1efcA6AGZoAH7NT26QKQBwGoB9TSG6gHpr4bqAe5mrECqAfz0RuoB-7SG6gH_5yxAqgHytwbsAgF0ggGEAEgpIECsQmXh1MzWOh52rkJl4dTM1joedr4CQGYCwG4DAGIFAHIFNbzm62f29q6YdAVAZgWAfgWAYAXAZIXCRIHCAEQAxiAAg&amp;sig=AOD64_1_Y1CxR2ChlolG-Pxv8tDrzGID2Q&amp;adurl=https://pages.dataiku.com/data-science-roi-toolkit/%3Futm_campaign%3DCONTENT%2520ROI%2520Toolkit%26utm_medium%3Dpaid-search%26utm_source%3Demea-adwords%26camp%3D14648494462%26creative%3D545837670890%26utm_term%3Ddata%2520science%26utm_campaign%3DZZZWP_G_SRCH_NOB_EXACT_AI%252BML_NAM_EN%26utm_source%3Dadwords%26utm_medium%3Dppc%26hsa_acc%3D3774963535%26hsa_cam%3D14648494462%26hsa_grp%3D127992682475%26hsa_ad%3D545837670890%26hsa_src%3Ds%26hsa_tgt%3Dkwd-2506849165%26hsa_kw%3Ddata%2520science%26hsa_mt%3De%26hsa_net%3Dadwords%26hsa_ver%3D3&amp;ms=[CLICK_MS]&amp;nx=[NX]&amp;ny=[NY]&amp;nb=[NB]" tabindex="-1"><tp-yt-paper-button animated="" aria-disabled="false" aria-label="VISIT SITE" class="style-scope ytd-button-renderer style-suggestive" elevation="0" id="button" role="button" tabindex="0"><!--css-build:shady--><yt-formatted-string class="style-scope ytd-button-renderer style-suggestive" id="text">VISIT SITE</yt-formatted-string><yt-icon class="style-scope ytd-button-renderer"><svg class="style-scope yt-icon" focusable="false" preserveaspectratio="xMidYMid meet" style="pointer-events: none; display: block; width: 100%; height: 100%;" viewbox="0 0 24 24"><g class="style-scope yt-icon"><path class="style-scope yt-icon" d="M21,21H3V3h9v1H4v16h16v-8h1V21z M15,3v1h4.32l-8.03,8.03L12,12.74l8-8V9h1V3H15z"></path></g></svg><!--css-build:shady--></yt-icon></tp-yt-paper-button></a></ytd-button-renderer></div>
# </div>
# </div>
# <div class="style-scope ytd-promoted-sparkles-web-renderer" id="menu"><ytd-menu-renderer class="style-scope ytd-promoted-sparkles-web-renderer" menu-active=""><!--css-build:shady--><div class="top-level-buttons style-scope ytd-menu-renderer" id="top-level-buttons-computed"></div>
# <yt-icon-button class="dropdown-trigger style-scope ytd-menu-renderer" id="button" touch-feedback=""><!--css-build:shady--><button aria-label="Action menu" class="style-scope yt-icon-button" id="button">
# <yt-icon class="style-scope ytd-menu-renderer"><svg class="style-scope yt-icon" focusable="false" preserveaspectratio="xMidYMid meet" style="pointer-events: none; display: block; width: 100%; height: 100%;" viewbox="0 0 24 24"><g class="style-scope yt-icon"><path class="style-scope yt-icon" d="M12,16.5c0.83,0,1.5,0.67,1.5,1.5s-0.67,1.5-1.5,1.5s-1.5-0.67-1.5-1.5S11.17,16.5,12,16.5z M10.5,12 c0,0.83,0.67,1.5,1.5,1.5s1.5-0.67,1.5-1.5s-0.67-1.5-1.5-1.5S10.5,11.17,10.5,12z M10.5,6c0,0.83,0.67,1.5,1.5,1.5 s1.5-0.67,1.5-1.5S12.83,4.5,12,4.5S10.5,5.17,10.5,6z"></path></g></svg><!--css-build:shady--></yt-icon>
# </button><yt-interaction class="circular style-scope yt-icon-button" id="interaction"><!--css-build:shady--><div class="stroke style-scope yt-interaction"></div><div class="fill style-scope yt-interaction"></div></yt-interaction></yt-icon-button>
# </ytd-menu-renderer></div>
# </ytd-promoted-sparkles-web-renderer></div>
# <div class="style-scope ytd-item-section-renderer" id="continuations"></div>
# </ytd-item-section-renderer><ytd-item-section-renderer class="style-scope ytd-section-list-renderer" use-height-hack=""><!--css-build:shady--><div class="style-scope ytd-item-section-renderer" id="header"></div>
# <div class="style-scope ytd-item-section-renderer" id="spinner-container">
# <tp-yt-paper-spinner-lite aria-hidden="true" class="style-scope ytd-item-section-renderer"><!--css-build:shady--><div class="style-scope tp-yt-paper-spinner-lite" id="spinnerContainer"><div class="spinner-layer style-scope tp-yt-paper-spinner-lite"><div class="circle-clipper left style-scope tp-yt-paper-spinner-lite"><div class="circle style-scope tp-yt-paper-spinner-lite"></div></div><div class="circle-clipper right style-scope tp-yt-paper-spinner-lite"><div class="circle style-scope tp-yt-paper-spinner-lite"></div></div></div></div></tp-yt-paper-spinner-lite>
# </div>
# <div class="style-scope ytd-item-section-renderer" id="contents"><ytd-promoted-sparkles-web-renderer class="style-scope ytd-item-section-renderer sparkles-light-cta" hide-hover-overlay="" web-search-layout="" web-search-layout-landscape=""><!--css-build:shady--><div class="style-scope ytd-promoted-sparkles-web-renderer" id="sparkles-container">
# <div class="style-scope ytd-promoted-sparkles-web-renderer" id="thumbnail-container">
# <div class="style-scope ytd-promoted-sparkles-web-renderer" id="thumbnail-deep-container">
# <yt-img-shadow class="style-scope ytd-promoted-sparkles-web-renderer no-transition" id="thumbnail" loaded="" object-fit="CONTAIN" style="background-color: transparent;"><!--css-build:shady--><img alt="" class="style-scope yt-img-shadow" id="img" src="https://tpc.googlesyndication.com/simgad/8031990141204312453"/></yt-img-shadow>
# <div class="style-scope ytd-promoted-sparkles-web-renderer" id="media-badge-search"><ytd-badge-supported-renderer class="style-scope ytd-promoted-sparkles-web-renderer" system-icons=""><!--css-build:shady-->
# <div class="badge badge-style-type-black style-scope ytd-badge-supported-renderer">
# <yt-icon class="style-scope ytd-badge-supported-renderer"><svg class="style-scope yt-icon" focusable="false" preserveaspectratio="xMidYMid meet" style="pointer-events: none; display: block; width: 100%; height: 100%;" viewbox="0 0 24 24"><g class="style-scope yt-icon"><path class="style-scope yt-icon" d="M21,21H3V3h9v1H4v16h16v-8h1V21z M15,3v1h4.32l-8.03,8.03L12,12.74l8-8V9h1V3H15z"></path></g></svg><!--css-build:shady--></yt-icon>
# <span class="style-scope ytd-badge-supported-renderer"></span>
# </div>
# <dom-repeat as="badge" class="style-scope ytd-badge-supported-renderer" id="repeat"><template is="dom-repeat"></template></dom-repeat>
# </ytd-badge-supported-renderer></div>
# <div class="style-scope ytd-promoted-sparkles-web-renderer" id="media-hover-overlay-search"></div>
# </div>
# <div class="style-scope ytd-promoted-sparkles-web-renderer" id="media-hover-overlay"></div>
# </div>
# <div class="style-scope ytd-promoted-sparkles-web-renderer" id="sparkles-body">
# <h3 class="style-scope ytd-promoted-sparkles-web-renderer" id="title" title="Data Science Certification - Learn From Home - Online Class">
#         Data Science Certification - Learn From Home - Online Class
#     </h3>
# <div class="style-scope ytd-promoted-sparkles-web-renderer" id="description">
#       Learn Machine Learning, Python, R, Spark, Hadoop &amp; Scala from Experts - Live, Online. Get hands on...
#     </div>
# <div class="style-scope ytd-promoted-sparkles-web-renderer" id="website-text-container">
# <ytd-badge-supported-renderer class="style-scope ytd-promoted-sparkles-web-renderer" id="ad-badge" system-icons=""><!--css-build:shady-->
# <div class="badge badge-style-type-ad style-scope ytd-badge-supported-renderer">
# <yt-icon class="style-scope ytd-badge-supported-renderer" disable-upgrade="" hidden="">
# </yt-icon>
# <span class="style-scope ytd-badge-supported-renderer">Ad</span>
# </div>
# <dom-repeat as="badge" class="style-scope ytd-badge-supported-renderer" id="repeat"><template is="dom-repeat"></template></dom-repeat>
# </ytd-badge-supported-renderer>
# <div class="style-scope ytd-promoted-sparkles-web-renderer" id="website-text">
#         https://www.simplilearn.com/data_science/certification
#       </div>
# </div>
# <div class="style-scope ytd-promoted-sparkles-web-renderer" id="action-button"><ytd-button-renderer button-renderer="true" class="style-scope ytd-promoted-sparkles-web-renderer style-suggestive" is-paper-button="" is-paper-button-with-icon="" use-keyboard-focused=""><a class="yt-simple-endpoint style-scope ytd-button-renderer" href="https://www.google.com/aclk?sa=l&amp;ai=C1Uh6RHCbYbC-OMi11gbn_LbICqSytptmvMrAkrULjfetqwkIABACILubuk4oAmCrzfOF8B6gAfOC9NsDyAEBqQJy4J1K29dMPqoEVU_Qog3-IxwSkX-Uy1vI0nf_8ljBNSbeZiFSxNbcuKeFkyO6rGTW3QXtbvXQ-4Ud27AfNBW64ZBSLVu5kS2aEWaSJlxVMBjk6aBoLJelALC3MKFEscfABMKql9vEAqAGUYAHqsjmNZAHAagH1NIbqAemvhuoB7masQKoB_PRG6gH7tIbqAf_nLECqAfK3BuwCAXSCAYQASCkgQKxCXWU2JsccIrWuQl1lNibHHCK1vgJAZgLAbgMAdAVAZgWAfgWAYAXAZIXCRIHCAEQAxiAAg&amp;sig=AOD64_2JCBCYWE_vKgYk5O6s7N3COz0YnA&amp;adurl=https://www.simplilearn.com/big-data-and-analytics/senior-data-scientist-masters-program-training%3F%26utm_source%3Dgoogle%26utm_medium%3Dcpc%26utm_term%3Ddata%2520science%26utm_content%3D9101905084-87164310850-431402864123%26utm_device%3Dc%26utm_campaign%3DSearch-DataCluster-DSAI-DSBI-ROW-ME-AllDevice-adgroup-Dsbi-DataScience-DataScience-New-Exact&amp;ms=[CLICK_MS]&amp;nx=[NX]&amp;ny=[NY]&amp;nb=[NB]" tabindex="-1"><tp-yt-paper-button animated="" aria-disabled="false" aria-label="VISIT SITE" class="style-scope ytd-button-renderer style-suggestive" elevation="0" id="button" role="button" tabindex="0"><!--css-build:shady--><yt-formatted-string class="style-scope ytd-button-renderer style-suggestive" id="text">VISIT SITE</yt-formatted-string><yt-icon class="style-scope ytd-button-renderer"><svg class="style-scope yt-icon" focusable="false" preserveaspectratio="xMidYMid meet" style="pointer-events: none; display: block; width: 100%; height: 100%;" viewbox="0 0 24 24"><g class="style-scope yt-icon"><path class="style-scope yt-icon" d="M21,21H3V3h9v1H4v16h16v-8h1V21z M15,3v1h4.32l-8.03,8.03L12,12.74l8-8V9h1V3H15z"></path></g></svg><!--css-build:shady--></yt-icon></tp-yt-paper-button></a></ytd-button-renderer></div>
# </div>
# </div>
# <div class="style-scope ytd-promoted-sparkles-web-renderer" id="menu"><ytd-menu-renderer class="style-scope ytd-promoted-sparkles-web-renderer" menu-active=""><!--css-build:shady--><div class="top-level-buttons style-scope ytd-menu-renderer" id="top-level-buttons-computed"></div>
# <yt-icon-button class="dropdown-trigger style-scope ytd-menu-renderer" id="button" touch-feedback=""><!--css-build:shady--><button aria-label="Action menu" class="style-scope yt-icon-button" id="button">
# <yt-icon class="style-scope ytd-menu-renderer"><svg class="style-scope yt-icon" focusable="false" preserveaspectratio="xMidYMid meet" style="pointer-events: none; display: block; width: 100%; height: 100%;" viewbox="0 0 24 24"><g class="style-scope yt-icon"><path class="style-scope yt-icon" d="M12,16.5c0.83,0,1.5,0.67,1.5,1.5s-0.67,1.5-1.5,1.5s-1.5-0.67-1.5-1.5S11.17,16.5,12,16.5z M10.5,12 c0,0.83,0.67,1.5,1.5,1.5s1.5-0.67,1.5-1.5s-0.67-1.5-1.5-1.5S10.5,11.17,10.5,12z M10.5,6c0,0.83,0.67,1.5,1.5,1.5 s1.5-0.67,1.5-1.5S12.83,4.5,12,4.5S10.5,5.17,10.5,6z"></path></g></svg><!--css-build:shady--></yt-icon>
# </button><yt-interaction class="circular style-scope yt-icon-button" id="interaction"><!--css-build:shady--><div class="stroke style-scope yt-interaction"></div><div class="fill style-scope yt-interaction"></div></yt-interaction></yt-icon-button>
# </ytd-menu-renderer></div>
# </ytd-promoted-sparkles-web-renderer></div>
# <div class="style-scope ytd-item-section-renderer" id="continuations"></div>
# </ytd-item-section-renderer><ytd-item-section-renderer can-show-more="" class="style-scope ytd-section-list-renderer" use-height-hack=""><!--css-build:shady--><div class="style-scope ytd-item-section-renderer" id="header"></div>
# <div class="style-scope ytd-item-section-renderer" id="spinner-container">
# <tp-yt-paper-spinner-lite aria-hidden="true" class="style-scope ytd-item-section-renderer"><!--css-build:shady--><div class="style-scope tp-yt-paper-spinner-lite" id="spinnerContainer"><div class="spinner-layer style-scope tp-yt-paper-spinner-lite"><div class="circle-clipper left style-scope tp-yt-paper-spinner-lite"><div class="circle style-scope tp-yt-paper-spinner-lite"></div></div><div class="circle-clipper right style-scope tp-yt-paper-spinner-lite"><div class="circle style-scope tp-yt-paper-spinner-lite"></div></div></div></div></tp-yt-paper-spinner-lite>
# </div>
# <div class="style-scope ytd-item-section-renderer" id="contents"><ytd-video-renderer class="style-scope ytd-item-section-renderer" inline-title-icon="" lockup="true" prominent-thumb-style="DEFAULT" style="position: relative;" use-prominent-thumbs=""><!--css-build:shady--><div class="style-scope ytd-video-renderer" id="dismissible">
# <ytd-thumbnail class="style-scope ytd-video-renderer" use-hovered-property=""><!--css-build:shady--><a aria-hidden="true" class="yt-simple-endpoint inline-block style-scope ytd-thumbnail" href="/watch?v=X3paOmcrTjQ" id="thumbnail" rel="null" tabindex="-1">
# <yt-img-shadow class="style-scope ytd-thumbnail no-transition" ftl-eligible="" loaded="" style="background-color: transparent;"><!--css-build:shady--><img alt="" class="style-scope yt-img-shadow" id="img" src="https://i.ytimg.com/vi/X3paOmcrTjQ/hq720.jpg?sqp=-oaymwEcCNAFEJQDSFXyq4qpAw4IARUAAIhCGAFwAcABBg==&amp;rs=AOn4CLDh4u00MJ3vNDVzld99emp2Z-gL6w" width="360"/></yt-img-shadow>
# <div class="style-scope ytd-thumbnail" id="overlays"><ytd-thumbnail-overlay-time-status-renderer class="style-scope ytd-thumbnail" overlay-style="DEFAULT"><!--css-build:shady--><yt-icon class="style-scope ytd-thumbnail-overlay-time-status-renderer" disable-upgrade="" hidden=""></yt-icon><span aria-label="4 minutes, 38 seconds" class="style-scope ytd-thumbnail-overlay-time-status-renderer" id="text">
#   4:38
# </span></ytd-thumbnail-overlay-time-status-renderer><ytd-thumbnail-overlay-now-playing-renderer class="style-scope ytd-thumbnail"><!--css-build:shady--><span class="style-scope ytd-thumbnail-overlay-now-playing-renderer">Now playing</span>
# <ytd-thumbnail-overlay-equalizer class="style-scope ytd-thumbnail-overlay-now-playing-renderer"><!--css-build:shady--><svg class="style-scope ytd-thumbnail-overlay-equalizer" id="equalizer" viewbox="0 0 55 95" xmlns="http://www.w3.org/2000/svg">
# <g class="style-scope ytd-thumbnail-overlay-equalizer">
# <rect class="bar style-scope ytd-thumbnail-overlay-equalizer" x="0"></rect>
# <rect class="bar style-scope ytd-thumbnail-overlay-equalizer" x="20"></rect>
# <rect class="bar style-scope ytd-thumbnail-overlay-equalizer" x="40"></rect>
# </g>
# </svg>
# </ytd-thumbnail-overlay-equalizer>
# </ytd-thumbnail-overlay-now-playing-renderer></div>
# <div class="style-scope ytd-thumbnail" id="mouseover-overlay"></div>
# <div class="style-scope ytd-thumbnail" id="hover-overlays"></div>
# </a>
# </ytd-thumbnail>
# <div class="text-wrapper style-scope ytd-video-renderer">
# <div class="style-scope ytd-video-renderer" id="meta">
# <div class="style-scope ytd-video-renderer" id="title-wrapper">
# <h3 class="title-and-badge style-scope ytd-video-renderer">
# <ytd-badge-supported-renderer class="style-scope ytd-video-renderer" disable-upgrade="" hidden="">
# </ytd-badge-supported-renderer>
# <a aria-label="Data Science In 5 Minutes | Data Science For Beginners | What Is Data Science? | Simplilearn by Simplilearn 2 years ago 4 minutes, 38 seconds 2,301,767 views" class="yt-simple-endpoint style-scope ytd-video-renderer" href="/watch?v=X3paOmcrTjQ" id="video-title" title="Data Science In 5 Minutes | Data Science For Beginners | What Is Data Science? | Simplilearn">
# <yt-icon class="style-scope ytd-video-renderer" hidden="" id="inline-title-icon"><!--css-build:shady--></yt-icon>
# <yt-formatted-string aria-label="Data Science In 5 Minutes | Data Science For Beginners | What Is Data Science? | Simplilearn by Simplilearn 2 years ago 4 minutes, 38 seconds 2,301,767 views" class="style-scope ytd-video-renderer">Data Science In 5 Minutes | Data Science For Beginners | What Is Data Science? | Simplilearn</yt-formatted-string>
# </a>
# </h3>
# <div class="style-scope ytd-video-renderer" id="menu"><ytd-menu-renderer class="style-scope ytd-video-renderer" menu-active=""><!--css-build:shady--><div class="top-level-buttons style-scope ytd-menu-renderer" id="top-level-buttons-computed"></div>
# <yt-icon-button class="dropdown-trigger style-scope ytd-menu-renderer" id="button" touch-feedback=""><!--css-build:shady--><button aria-label="Action menu" class="style-scope yt-icon-button" id="button">
# <yt-icon class="style-scope ytd-menu-renderer"><svg class="style-scope yt-icon" focusable="false" preserveaspectratio="xMidYMid meet" style="pointer-events: none; display: block; width: 100%; height: 100%;" viewbox="0 0 24 24"><g class="style-scope yt-icon"><path class="style-scope yt-icon" d="M12,16.5c0.83,0,1.5,0.67,1.5,1.5s-0.67,1.5-1.5,1.5s-1.5-0.67-1.5-1.5S11.17,16.5,12,16.5z M10.5,12 c0,0.83,0.67,1.5,1.5,1.5s1.5-0.67,1.5-1.5s-0.67-1.5-1.5-1.5S10.5,11.17,10.5,12z M10.5,6c0,0.83,0.67,1.5,1.5,1.5 s1.5-0.67,1.5-1.5S12.83,4.5,12,4.5S10.5,5.17,10.5,6z"></path></g></svg><!--css-build:shady--></yt-icon>
# </button><yt-interaction class="circular style-scope yt-icon-button" id="interaction"><!--css-build:shady--><div class="stroke style-scope yt-interaction"></div><div class="fill style-scope yt-interaction"></div></yt-interaction></yt-icon-button>
# </ytd-menu-renderer></div>
# </div>
# <ytd-video-meta-block class="style-scope ytd-video-renderer"><!--css-build:shady-->
# <div class="style-scope ytd-video-meta-block" id="metadata">
# <div class="style-scope ytd-video-meta-block" hidden="" id="byline-container">
# <ytd-channel-name class="style-scope ytd-video-meta-block" id="channel-name"><!--css-build:shady--><div class="style-scope ytd-channel-name" id="container">
# <div class="style-scope ytd-channel-name" id="text-container">
# <yt-formatted-string class="style-scope ytd-channel-name complex-string" ellipsis-truncate="" has-link-only_="" id="text" title=""><a class="yt-simple-endpoint style-scope yt-formatted-string" dir="auto" href="/user/Simplilearn" spellcheck="false">Simplilearn</a></yt-formatted-string>
# </div>
# <tp-yt-paper-tooltip class="style-scope ytd-channel-name" fit-to-visible-bounds="" role="tooltip" tabindex="-1"><!--css-build:shady--><div class="hidden style-scope tp-yt-paper-tooltip" id="tooltip">
#
#     Simplilearn
#
# </div>
# </tp-yt-paper-tooltip>
# </div>
# <ytd-badge-supported-renderer class="style-scope ytd-channel-name" system-icons=""><!--css-build:shady-->
# <div aria-label="Verified" class="badge badge-style-type-verified style-scope ytd-badge-supported-renderer">
# <yt-icon class="style-scope ytd-badge-supported-renderer"><svg class="style-scope yt-icon" focusable="false" preserveaspectratio="xMidYMid meet" style="pointer-events: none; display: block; width: 100%; height: 100%;" viewbox="0 0 24 24"><g class="style-scope yt-icon"><path class="style-scope yt-icon" d="M12,2C6.5,2,2,6.5,2,12c0,5.5,4.5,10,10,10s10-4.5,10-10C22,6.5,17.5,2,12,2z M9.8,17.3l-4.2-4.1L7,11.8l2.8,2.7L17,7.4 l1.4,1.4L9.8,17.3z"></path></g></svg><!--css-build:shady--></yt-icon>
# <span class="style-scope ytd-badge-supported-renderer"></span>
# </div>
# <dom-repeat as="badge" class="style-scope ytd-badge-supported-renderer" id="repeat"><template is="dom-repeat"></template></dom-repeat>
# </ytd-badge-supported-renderer>
# </ytd-channel-name>
# <div class="style-scope ytd-video-meta-block" id="separator">•</div>
# </div>
# <div class="style-scope ytd-video-meta-block" id="metadata-line">
# <span class="style-scope ytd-video-meta-block">2.3M views</span>
# <span class="style-scope ytd-video-meta-block">2 years ago</span>
# <dom-repeat class="style-scope ytd-video-meta-block" strip-whitespace=""><template is="dom-repeat"></template></dom-repeat>
# </div>
# </div>
# <div class="style-scope ytd-video-meta-block" id="additional-metadata-line">
# <dom-repeat class="style-scope ytd-video-meta-block"><template is="dom-repeat"></template></dom-repeat>
# </div>
# </ytd-video-meta-block>
# </div>
# <div class="style-scope ytd-video-renderer" id="channel-info">
# <a aria-label="Go to channel" class="style-scope ytd-video-renderer" href="/user/Simplilearn">
# <yt-img-shadow class="style-scope ytd-video-renderer no-transition" loaded="" style="background-color: transparent;" width="24"><!--css-build:shady--><img alt="" class="style-scope yt-img-shadow" id="img" src="https://yt3.ggpht.com/ytc/AKedOLTaNnIZrEVNHk-OgfTRlO1n2aeAZ657f5FrG-5EaA=s68-c-k-c0x00ffffff-no-rj" width="24"/></yt-img-shadow>
# </a>
# <ytd-channel-name class="long-byline style-scope ytd-video-renderer" id="channel-name" wrap-text="true"><!--css-build:shady--><div class="style-scope ytd-channel-name" id="container">
# <div class="style-scope ytd-channel-name" id="text-container">
# <yt-formatted-string class="style-scope ytd-channel-name" has-link-only_="" id="text" title=""><a class="yt-simple-endpoint style-scope yt-formatted-string" dir="auto" href="/user/Simplilearn" spellcheck="false">Simplilearn</a></yt-formatted-string>
# </div>
# <tp-yt-paper-tooltip class="style-scope ytd-channel-name" fit-to-visible-bounds="" role="tooltip" tabindex="-1"><!--css-build:shady--><div class="hidden style-scope tp-yt-paper-tooltip" id="tooltip">
#
#     Simplilearn
#
# </div>
# </tp-yt-paper-tooltip>
# </div>
# <ytd-badge-supported-renderer class="style-scope ytd-channel-name" system-icons=""><!--css-build:shady-->
# <div aria-label="Verified" class="badge badge-style-type-verified style-scope ytd-badge-supported-renderer">
# <yt-icon class="style-scope ytd-badge-supported-renderer"><svg class="style-scope yt-icon" focusable="false" preserveaspectratio="xMidYMid meet" style="pointer-events: none; display: block; width: 100%; height: 100%;" viewbox="0 0 24 24"><g class="style-scope yt-icon"><path class="style-scope yt-icon" d="M12,2C6.5,2,2,6.5,2,12c0,5.5,4.5,10,10,10s10-4.5,10-10C22,6.5,17.5,2,12,2z M9.8,17.3l-4.2-4.1L7,11.8l2.8,2.7L17,7.4 l1.4,1.4L9.8,17.3z"></path></g></svg><!--css-build:shady--></yt-icon>
# <span class="style-scope ytd-badge-supported-renderer"></span>
# </div>
# <dom-repeat as="badge" class="style-scope ytd-badge-supported-renderer" id="repeat"><template is="dom-repeat"></template></dom-repeat>
# </ytd-badge-supported-renderer>
# </ytd-channel-name>
# </div>
# <yt-formatted-string class="style-scope ytd-video-renderer" hidden="" id="description-text"><!--css-build:shady--></yt-formatted-string>
# <div class="metadata-snippet-container style-scope ytd-video-renderer">
# <a class="yt-simple-endpoint metadata-snippet-timestamp style-scope ytd-video-renderer" hidden="">
# <span class="style-scope ytd-video-renderer" id="time"></span>
# <yt-formatted-string class="metadata-snippet-text-navigation style-scope ytd-video-renderer"><span class="style-scope yt-formatted-string" dir="auto">Below topics are explained in this </span><span class="bold style-scope yt-formatted-string" dir="auto">Data Science</span><span class="style-scope yt-formatted-string" dir="auto"> tutorial: 0:00 Introduction 0:10 Life of a </span><span class="bold style-scope yt-formatted-string" dir="auto">Data Scientist</span><span class="style-scope yt-formatted-string" dir="auto"> - Steps in </span><span class="bold style-scope yt-formatted-string" dir="auto">Data Science</span><span class="style-scope yt-formatted-string" dir="auto"> ...</span></yt-formatted-string>
# </a>
# <yt-formatted-string class="metadata-snippet-text style-scope ytd-video-renderer"><span class="style-scope yt-formatted-string" dir="auto">Below topics are explained in this </span><span class="bold style-scope yt-formatted-string" dir="auto">Data Science</span><span class="style-scope yt-formatted-string" dir="auto"> tutorial: 0:00 Introduction 0:10 Life of a </span><span class="bold style-scope yt-formatted-string" dir="auto">Data Scientist</span><span class="style-scope yt-formatted-string" dir="auto"> - Steps in </span><span class="bold style-scope yt-formatted-string" dir="auto">Data Science</span><span class="style-scope yt-formatted-string" dir="auto"> ...</span></yt-formatted-string>
# <tp-yt-paper-tooltip class="style-scope ytd-video-renderer" role="tooltip" tabindex="-1"><!--css-build:shady--><div class="hidden style-scope tp-yt-paper-tooltip" id="tooltip">
#   From the video description
# </div>
# </tp-yt-paper-tooltip>
# </div>
# <dom-repeat class="style-scope ytd-video-renderer"><template is="dom-repeat"></template></dom-repeat>
# <ytd-badge-supported-renderer class="style-scope ytd-video-renderer" disable-upgrade="" hidden="" id="badges">
# </ytd-badge-supported-renderer>
# <div class="style-scope ytd-video-renderer" id="expandable-metadata"></div>
# <div class="style-scope ytd-video-renderer" id="buttons"></div>
# </div>
# </div>
# <div class="style-scope ytd-video-renderer" id="dismissed"></div>
# <yt-interaction class="extended"><!--css-build:shady--><div class="stroke style-scope yt-interaction"></div><div class="fill style-scope yt-interaction"></div></yt-interaction></ytd-video-renderer><ytd-video-renderer class="style-scope ytd-item-section-renderer" inline-title-icon="" lockup="true" prominent-thumb-style="DEFAULT" style="position: relative;" use-prominent-thumbs=""><!--css-build:shady--><div class="style-scope ytd-video-renderer" id="dismissible">
# <ytd-thumbnail class="style-scope ytd-video-renderer" use-hovered-property=""><!--css-build:shady--><a aria-hidden="true" class="yt-simple-endpoint inline-block style-scope ytd-thumbnail" href="/watch?v=ua-CiDNNj30" id="thumbnail" rel="null" tabindex="-1">
# <yt-img-shadow class="style-scope ytd-thumbnail no-transition" ftl-eligible="" loaded="" style="background-color: transparent;"><!--css-build:shady--><img alt="" class="style-scope yt-img-shadow" id="img" src="https://i.ytimg.com/vi/ua-CiDNNj30/hq720.jpg?sqp=-oaymwEcCNAFEJQDSFXyq4qpAw4IARUAAIhCGAFwAcABBg==&amp;rs=AOn4CLAkCi1evX3P7ePC49in4NOjwJ3yjQ" width="360"/></yt-img-shadow>
# <div class="style-scope ytd-thumbnail" id="overlays"><ytd-thumbnail-overlay-time-status-renderer class="style-scope ytd-thumbnail" overlay-style="DEFAULT"><!--css-build:shady--><yt-icon class="style-scope ytd-thumbnail-overlay-time-status-renderer" disable-upgrade="" hidden=""></yt-icon><span aria-label="5 hours, 52 minutes, 9 seconds" class="style-scope ytd-thumbnail-overlay-time-status-renderer" id="text">
#   5:52:09
# </span></ytd-thumbnail-overlay-time-status-renderer><ytd-thumbnail-overlay-now-playing-renderer class="style-scope ytd-thumbnail"><!--css-build:shady--><span class="style-scope ytd-thumbnail-overlay-now-playing-renderer">Now playing</span>
# <ytd-thumbnail-overlay-equalizer class="style-scope ytd-thumbnail-overlay-now-playing-renderer"><!--css-build:shady--><svg class="style-scope ytd-thumbnail-overlay-equalizer" id="equalizer" viewbox="0 0 55 95" xmlns="http://www.w3.org/2000/svg">
# <g class="style-scope ytd-thumbnail-overlay-equalizer">
# <rect class="bar style-scope ytd-thumbnail-overlay-equalizer" x="0"></rect>
# <rect class="bar style-scope ytd-thumbnail-overlay-equalizer" x="20"></rect>
# <rect class="bar style-scope ytd-thumbnail-overlay-equalizer" x="40"></rect>
# </g>
# </svg>
# </ytd-thumbnail-overlay-equalizer>
# </ytd-thumbnail-overlay-now-playing-renderer></div>
# <div class="style-scope ytd-thumbnail" id="mouseover-overlay"></div>
# <div class="style-scope ytd-thumbnail" id="hover-overlays"></div>
# </a>
# </ytd-thumbnail>
# <div class="text-wrapper style-scope ytd-video-renderer">
# <div class="style-scope ytd-video-renderer" id="meta">
# <div class="style-scope ytd-video-renderer" id="title-wrapper">
# <h3 class="title-and-badge style-scope ytd-video-renderer">
# <ytd-badge-supported-renderer class="style-scope ytd-video-renderer" disable-upgrade="" hidden="">
# </ytd-badge-supported-renderer>
# <a aria-label="Learn Data Science Tutorial - Full Course for Beginners by freeCodeCamp.org 2 years ago 5 hours, 52 minutes 1,628,692 views" class="yt-simple-endpoint style-scope ytd-video-renderer" href="/watch?v=ua-CiDNNj30" id="video-title" title="Learn Data Science Tutorial - Full Course for Beginners">
# <yt-icon class="style-scope ytd-video-renderer" hidden="" id="inline-title-icon"><!--css-build:shady--></yt-icon>
# <yt-formatted-string aria-label="Learn Data Science Tutorial - Full Course for Beginners by freeCodeCamp.org 2 years ago 5 hours, 52 minutes 1,628,692 views" class="style-scope ytd-video-renderer">Learn Data Science Tutorial - Full Course for Beginners</yt-formatted-string>
# </a>
# </h3>
# <div class="style-scope ytd-video-renderer" id="menu"><ytd-menu-renderer class="style-scope ytd-video-renderer" menu-active=""><!--css-build:shady--><div class="top-level-buttons style-scope ytd-menu-renderer" id="top-level-buttons-computed"></div>
# <yt-icon-button class="dropdown-trigger style-scope ytd-menu-renderer" id="button" touch-feedback=""><!--css-build:shady--><button aria-label="Action menu" class="style-scope yt-icon-button" id="button">
# <yt-icon class="style-scope ytd-menu-renderer"><svg class="style-scope yt-icon" focusable="false" preserveaspectratio="xMidYMid meet" style="pointer-events: none; display: block; width: 100%; height: 100%;" viewbox="0 0 24 24"><g class="style-scope yt-icon"><path class="style-scope yt-icon" d="M12,16.5c0.83,0,1.5,0.67,1.5,1.5s-0.67,1.5-1.5,1.5s-1.5-0.67-1.5-1.5S11.17,16.5,12,16.5z M10.5,12 c0,0.83,0.67,1.5,1.5,1.5s1.5-0.67,1.5-1.5s-0.67-1.5-1.5-1.5S10.5,11.17,10.5,12z M10.5,6c0,0.83,0.67,1.5,1.5,1.5 s1.5-0.67,1.5-1.5S12.83,4.5,12,4.5S10.5,5.17,10.5,6z"></path></g></svg><!--css-build:shady--></yt-icon>
# </button><yt-interaction class="circular style-scope yt-icon-button" id="interaction"><!--css-build:shady--><div class="stroke style-scope yt-interaction"></div><div class="fill style-scope yt-interaction"></div></yt-interaction></yt-icon-button>
# </ytd-menu-renderer></div>
# </div>
# <ytd-video-meta-block class="style-scope ytd-video-renderer"><!--css-build:shady-->
# <div class="style-scope ytd-video-meta-block" id="metadata">
# <div class="style-scope ytd-video-meta-block" hidden="" id="byline-container">
# <ytd-channel-name class="style-scope ytd-video-meta-block" id="channel-name"><!--css-build:shady--><div class="style-scope ytd-channel-name" id="container">
# <div class="style-scope ytd-channel-name" id="text-container">
# <yt-formatted-string class="style-scope ytd-channel-name complex-string" ellipsis-truncate="" has-link-only_="" id="text" title=""><a class="yt-simple-endpoint style-scope yt-formatted-string" dir="auto" href="/channel/UC8butISFwT-Wl7EV0hUK0BQ" spellcheck="false">freeCodeCamp.org</a></yt-formatted-string>
# </div>
# <tp-yt-paper-tooltip class="style-scope ytd-channel-name" fit-to-visible-bounds="" role="tooltip" tabindex="-1"><!--css-build:shady--><div class="hidden style-scope tp-yt-paper-tooltip" id="tooltip">
#
#     freeCodeCamp.org
#
# </div>
# </tp-yt-paper-tooltip>
# </div>
# <ytd-badge-supported-renderer class="style-scope ytd-channel-name" system-icons=""><!--css-build:shady-->
# <div aria-label="Verified" class="badge badge-style-type-verified style-scope ytd-badge-supported-renderer">
# <yt-icon class="style-scope ytd-badge-supported-renderer"><svg class="style-scope yt-icon" focusable="false" preserveaspectratio="xMidYMid meet" style="pointer-events: none; display: block; width: 100%; height: 100%;" viewbox="0 0 24 24"><g class="style-scope yt-icon"><path class="style-scope yt-icon" d="M12,2C6.5,2,2,6.5,2,12c0,5.5,4.5,10,10,10s10-4.5,10-10C22,6.5,17.5,2,12,2z M9.8,17.3l-4.2-4.1L7,11.8l2.8,2.7L17,7.4 l1.4,1.4L9.8,17.3z"></path></g></svg><!--css-build:shady--></yt-icon>
# <span class="style-scope ytd-badge-supported-renderer"></span>
# </div>
# <dom-repeat as="badge" class="style-scope ytd-badge-supported-renderer" id="repeat"><template is="dom-repeat"></template></dom-repeat>
# </ytd-badge-supported-renderer>
# </ytd-channel-name>
# <div class="style-scope ytd-video-meta-block" id="separator">•</div>
# </div>
# <div class="style-scope ytd-video-meta-block" id="metadata-line">
# <span class="style-scope ytd-video-meta-block">1.6M views</span>
# <span class="style-scope ytd-video-meta-block">2 years ago</span>
# <dom-repeat class="style-scope ytd-video-meta-block" strip-whitespace=""><template is="dom-repeat"></template></dom-repeat>
# </div>
# </div>
# <div class="style-scope ytd-video-meta-block" id="additional-metadata-line">
# <dom-repeat class="style-scope ytd-video-meta-block"><template is="dom-repeat"></template></dom-repeat>
# </div>
# </ytd-video-meta-block>
# </div>
# <div class="style-scope ytd-video-renderer" id="channel-info">
# <a aria-label="Go to channel" class="style-scope ytd-video-renderer" href="/channel/UC8butISFwT-Wl7EV0hUK0BQ">
# <yt-img-shadow class="style-scope ytd-video-renderer no-transition" loaded="" style="background-color: transparent;" width="24"><!--css-build:shady--><img alt="" class="style-scope yt-img-shadow" id="img" src="https://yt3.ggpht.com/ytc/AKedOLTtJvQ1Vfew91vemeLaLdhjOwGx3tTBLlreK_QUyA=s68-c-k-c0x00ffffff-no-rj" width="24"/></yt-img-shadow>
# </a>
# <ytd-channel-name class="long-byline style-scope ytd-video-renderer" id="channel-name" wrap-text="true"><!--css-build:shady--><div class="style-scope ytd-channel-name" id="container">
# <div class="style-scope ytd-channel-name" id="text-container">
# <yt-formatted-string class="style-scope ytd-channel-name" has-link-only_="" id="text" title=""><a class="yt-simple-endpoint style-scope yt-formatted-string" dir="auto" href="/channel/UC8butISFwT-Wl7EV0hUK0BQ" spellcheck="false">freeCodeCamp.org</a></yt-formatted-string>
# </div>
# <tp-yt-paper-tooltip class="style-scope ytd-channel-name" fit-to-visible-bounds="" role="tooltip" tabindex="-1"><!--css-build:shady--><div class="hidden style-scope tp-yt-paper-tooltip" id="tooltip">
#
#     freeCodeCamp.org
#
# </div>
# </tp-yt-paper-tooltip>
# </div>
# <ytd-badge-supported-renderer class="style-scope ytd-channel-name" system-icons=""><!--css-build:shady-->
# <div aria-label="Verified" class="badge badge-style-type-verified style-scope ytd-badge-supported-renderer">
# <yt-icon class="style-scope ytd-badge-supported-renderer"><svg class="style-scope yt-icon" focusable="false" preserveaspectratio="xMidYMid meet" style="pointer-events: none; display: block; width: 100%; height: 100%;" viewbox="0 0 24 24"><g class="style-scope yt-icon"><path class="style-scope yt-icon" d="M12,2C6.5,2,2,6.5,2,12c0,5.5,4.5,10,10,10s10-4.5,10-10C22,6.5,17.5,2,12,2z M9.8,17.3l-4.2-4.1L7,11.8l2.8,2.7L17,7.4 l1.4,1.4L9.8,17.3z"></path></g></svg><!--css-build:shady--></yt-icon>
# <span class="style-scope ytd-badge-supported-renderer"></span>
# </div>
# <dom-repeat as="badge" class="style-scope ytd-badge-supported-renderer" id="repeat"><template is="dom-repeat"></template></dom-repeat>
# </ytd-badge-supported-renderer>
# </ytd-channel-name>
# </div>
# <yt-formatted-string class="style-scope ytd-video-renderer" hidden="" id="description-text"><!--css-build:shady--></yt-formatted-string>
# <div class="metadata-snippet-container style-scope ytd-video-renderer">
# <a class="yt-simple-endpoint metadata-snippet-timestamp style-scope ytd-video-renderer" hidden="">
# <span class="style-scope ytd-video-renderer" id="time"></span>
# <yt-formatted-string class="metadata-snippet-text-navigation style-scope ytd-video-renderer"><span class="style-scope yt-formatted-string" dir="auto">Learn </span><span class="bold style-scope yt-formatted-string" dir="auto">Data Science</span><span class="style-scope yt-formatted-string" dir="auto"> is this full tutorial course for absolute beginners. </span><span class="bold style-scope yt-formatted-string" dir="auto">Data science</span><span class="style-scope yt-formatted-string" dir="auto"> is considered the "sexiest job of the 21st ...</span></yt-formatted-string>
# </a>
# <yt-formatted-string class="metadata-snippet-text style-scope ytd-video-renderer"><span class="style-scope yt-formatted-string" dir="auto">Learn </span><span class="bold style-scope yt-formatted-string" dir="auto">Data Science</span><span class="style-scope yt-formatted-string" dir="auto"> is this full tutorial course for absolute beginners. </span><span class="bold style-scope yt-formatted-string" dir="auto">Data science</span><span class="style-scope yt-formatted-string" dir="auto"> is considered the "sexiest job of the 21st ...</span></yt-formatted-string>
# <tp-yt-paper-tooltip class="style-scope ytd-video-renderer" role="tooltip" tabindex="-1"><!--css-build:shady--><div class="hidden style-scope tp-yt-paper-tooltip" id="tooltip">
#   From the video description
# </div>
# </tp-yt-paper-tooltip>
# </div>
# <dom-repeat class="style-scope ytd-video-renderer"><template is="dom-repeat"></template></dom-repeat>
# <ytd-badge-supported-renderer class="style-scope ytd-video-renderer" id="badges" system-icons=""><!--css-build:shady-->
# <div aria-label="Closed captions" class="badge badge-style-type-simple style-scope ytd-badge-supported-renderer">
# <yt-icon class="style-scope ytd-badge-supported-renderer" disable-upgrade="" hidden="">
# </yt-icon>
# <span class="style-scope ytd-badge-supported-renderer">Subtitles</span>
# </div>
# <dom-repeat as="badge" class="style-scope ytd-badge-supported-renderer" id="repeat"><template is="dom-repeat"></template></dom-repeat>
# </ytd-badge-supported-renderer>
# <div class="style-scope ytd-video-renderer" id="expandable-metadata"></div>
# <div class="style-scope ytd-video-renderer" id="buttons"></div>
# </div>
# </div>
# <div class="style-scope ytd-video-renderer" id="dismissed"></div>
# <yt-interaction class="extended"><!--css-build:shady--><div class="stroke style-scope yt-interaction"></div><div class="fill style-scope yt-interaction"></div></yt-interaction></ytd-video-renderer><ytd-video-renderer class="style-scope ytd-item-section-renderer" inline-title-icon="" lockup="true" prominent-thumb-style="DEFAULT" style="position: relative;" use-prominent-thumbs=""><!--css-build:shady--><div class="style-scope ytd-video-renderer" id="dismissible">
# <ytd-thumbnail class="style-scope ytd-video-renderer" use-hovered-property=""><!--css-build:shady--><a aria-hidden="true" class="yt-simple-endpoint inline-block style-scope ytd-thumbnail" href="/watch?v=xC-c7E5PK0Y" id="thumbnail" rel="null" tabindex="-1">
# <yt-img-shadow class="style-scope ytd-thumbnail no-transition" ftl-eligible="" loaded="" style="background-color: transparent;"><!--css-build:shady--><img alt="" class="style-scope yt-img-shadow" id="img" src="https://i.ytimg.com/vi/xC-c7E5PK0Y/hq720.jpg?sqp=-oaymwEcCNAFEJQDSFXyq4qpAw4IARUAAIhCGAFwAcABBg==&amp;rs=AOn4CLB8cHioQUgPnIGX67liQt5Oh0zJDA" width="360"/></yt-img-shadow>
# <div class="style-scope ytd-thumbnail" id="overlays"><ytd-thumbnail-overlay-time-status-renderer class="style-scope ytd-thumbnail" overlay-style="DEFAULT"><!--css-build:shady--><yt-icon class="style-scope ytd-thumbnail-overlay-time-status-renderer" disable-upgrade="" hidden=""></yt-icon><span aria-label="11 minutes, 9 seconds" class="style-scope ytd-thumbnail-overlay-time-status-renderer" id="text">
#   11:09
# </span></ytd-thumbnail-overlay-time-status-renderer><ytd-thumbnail-overlay-now-playing-renderer class="style-scope ytd-thumbnail"><!--css-build:shady--><span class="style-scope ytd-thumbnail-overlay-now-playing-renderer">Now playing</span>
# <ytd-thumbnail-overlay-equalizer class="style-scope ytd-thumbnail-overlay-now-playing-renderer"><!--css-build:shady--><svg class="style-scope ytd-thumbnail-overlay-equalizer" id="equalizer" viewbox="0 0 55 95" xmlns="http://www.w3.org/2000/svg">
# <g class="style-scope ytd-thumbnail-overlay-equalizer">
# <rect class="bar style-scope ytd-thumbnail-overlay-equalizer" x="0"></rect>
# <rect class="bar style-scope ytd-thumbnail-overlay-equalizer" x="20"></rect>
# <rect class="bar style-scope ytd-thumbnail-overlay-equalizer" x="40"></rect>
# </g>
# </svg>
# </ytd-thumbnail-overlay-equalizer>
# </ytd-thumbnail-overlay-now-playing-renderer></div>
# <div class="style-scope ytd-thumbnail" id="mouseover-overlay"></div>
# <div class="style-scope ytd-thumbnail" id="hover-overlays"></div>
# </a>
# </ytd-thumbnail>
# <div class="text-wrapper style-scope ytd-video-renderer">
# <div class="style-scope ytd-video-renderer" id="meta">
# <div class="style-scope ytd-video-renderer" id="title-wrapper">
# <h3 class="title-and-badge style-scope ytd-video-renderer">
# <ytd-badge-supported-renderer class="style-scope ytd-video-renderer" disable-upgrade="" hidden="">
# </ytd-badge-supported-renderer>
# <a aria-label="What REALLY is Data Science? Told by a Data Scientist by Joma Tech 3 years ago 11 minutes, 9 seconds 2,494,334 views" class="yt-simple-endpoint style-scope ytd-video-renderer" href="/watch?v=xC-c7E5PK0Y" id="video-title" title="What REALLY is Data Science? Told by a Data Scientist">
# <yt-icon class="style-scope ytd-video-renderer" hidden="" id="inline-title-icon"><!--css-build:shady--></yt-icon>
# <yt-formatted-string aria-label="What REALLY is Data Science? Told by a Data Scientist by Joma Tech 3 years ago 11 minutes, 9 seconds 2,494,334 views" class="style-scope ytd-video-renderer">What REALLY is Data Science? Told by a Data Scientist</yt-formatted-string>
# </a>
# </h3>
# <div class="style-scope ytd-video-renderer" id="menu"><ytd-menu-renderer class="style-scope ytd-video-renderer" menu-active=""><!--css-build:shady--><div class="top-level-buttons style-scope ytd-menu-renderer" id="top-level-buttons-computed"></div>
# <yt-icon-button class="dropdown-trigger style-scope ytd-menu-renderer" id="button" touch-feedback=""><!--css-build:shady--><button aria-label="Action menu" class="style-scope yt-icon-button" id="button">
# <yt-icon class="style-scope ytd-menu-renderer"><svg class="style-scope yt-icon" focusable="false" preserveaspectratio="xMidYMid meet" style="pointer-events: none; display: block; width: 100%; height: 100%;" viewbox="0 0 24 24"><g class="style-scope yt-icon"><path class="style-scope yt-icon" d="M12,16.5c0.83,0,1.5,0.67,1.5,1.5s-0.67,1.5-1.5,1.5s-1.5-0.67-1.5-1.5S11.17,16.5,12,16.5z M10.5,12 c0,0.83,0.67,1.5,1.5,1.5s1.5-0.67,1.5-1.5s-0.67-1.5-1.5-1.5S10.5,11.17,10.5,12z M10.5,6c0,0.83,0.67,1.5,1.5,1.5 s1.5-0.67,1.5-1.5S12.83,4.5,12,4.5S10.5,5.17,10.5,6z"></path></g></svg><!--css-build:shady--></yt-icon>
# </button><yt-interaction class="circular style-scope yt-icon-button" id="interaction"><!--css-build:shady--><div class="stroke style-scope yt-interaction"></div><div class="fill style-scope yt-interaction"></div></yt-interaction></yt-icon-button>
# </ytd-menu-renderer></div>
# </div>
# <ytd-video-meta-block class="style-scope ytd-video-renderer"><!--css-build:shady-->
# <div class="style-scope ytd-video-meta-block" id="metadata">
# <div class="style-scope ytd-video-meta-block" hidden="" id="byline-container">
# <ytd-channel-name class="style-scope ytd-video-meta-block" id="channel-name"><!--css-build:shady--><div class="style-scope ytd-channel-name" id="container">
# <div class="style-scope ytd-channel-name" id="text-container">
# <yt-formatted-string class="style-scope ytd-channel-name complex-string" ellipsis-truncate="" has-link-only_="" id="text" title=""><a class="yt-simple-endpoint style-scope yt-formatted-string" dir="auto" href="/channel/UCV0qA-eDDICsRR9rPcnG7tw" spellcheck="false">Joma Tech</a></yt-formatted-string>
# </div>
# <tp-yt-paper-tooltip class="style-scope ytd-channel-name" fit-to-visible-bounds="" role="tooltip" tabindex="-1"><!--css-build:shady--><div class="hidden style-scope tp-yt-paper-tooltip" id="tooltip">
#
#     Joma Tech
#
# </div>
# </tp-yt-paper-tooltip>
# </div>
# <ytd-badge-supported-renderer class="style-scope ytd-channel-name" system-icons=""><!--css-build:shady-->
# <div aria-label="Verified" class="badge badge-style-type-verified style-scope ytd-badge-supported-renderer">
# ...
# <div class="style-scope ytd-channel-name" id="text-container">
# <yt-formatted-string class="style-scope ytd-channel-name complex-string" ellipsis-truncate="" has-link-only_="" id="text" title=""><a class="yt-simple-endpoint style-scope yt-formatted-string" dir="auto" href="/channel/UCteRPiisgIoHtMgqHegpWAQ" spellcheck="false">Sundas Khalid</a></yt-formatted-string>
# </div>
# <tp-yt-paper-tooltip class="style-scope ytd-channel-name" fit-to-visible-bounds="" role="tooltip" tabindex="-1"><!--css-build:shady--><div class="hidden style-scope tp-yt-paper-tooltip" id="tooltip">
#
#     Sundas Khalid
#
# </div>
# </tp-yt-paper-tooltip>
# </div>
# <ytd-badge-supported-renderer class="style-scope ytd-channel-name" disable-upgrade="" hidden="">
# </ytd-badge-supported-renderer>
# </ytd-channel-name>
# <div class="style-scope ytd-video-meta-block" id="separator">•</div>
# </div>
# <div class="style-scope ytd-video-meta-block" id="metadata-line">
# <span class="style-scope ytd-video-meta-block">20K views</span>
# <span class="style-scope ytd-video-meta-block">3 weeks ago</span>
# <dom-repeat class="style-scope ytd-video-meta-block" strip-whitespace=""><template is="dom-repeat"></template></dom-repeat>
# </div>
# </div>
# <div class="style-scope ytd-video-meta-block" id="additional-metadata-line">
# <dom-repeat class="style-scope ytd-video-meta-block"><template is="dom-repeat"></template></dom-repeat>
# </div>
# </ytd-video-meta-block>
# </div>
# <div class="style-scope ytd-video-renderer" id="channel-info">
# <a aria-label="Go to channel" class="style-scope ytd-video-renderer" href="/channel/UCteRPiisgIoHtMgqHegpWAQ">
# <yt-img-shadow class="style-scope ytd-video-renderer no-transition empty" style="background-color: transparent;" width="24"><!--css-build:shady--><img alt="" class="style-scope yt-img-shadow" id="img" width="24"/></yt-img-shadow>
# </a>
# <ytd-channel-name class="long-byline style-scope ytd-video-renderer" id="channel-name" wrap-text="true"><!--css-build:shady--><div class="style-scope ytd-channel-name" id="container">
# <div class="style-scope ytd-channel-name" id="text-container">
# <yt-formatted-string class="style-scope ytd-channel-name" has-link-only_="" id="text" title=""><a class="yt-simple-endpoint style-scope yt-formatted-string" dir="auto" href="/channel/UCteRPiisgIoHtMgqHegpWAQ" spellcheck="false">Sundas Khalid</a></yt-formatted-string>
# </div>
# <tp-yt-paper-tooltip class="style-scope ytd-channel-name" fit-to-visible-bounds="" role="tooltip" tabindex="-1"><!--css-build:shady--><div class="hidden style-scope tp-yt-paper-tooltip" id="tooltip">
#
#     Sundas Khalid
#
# </div>
# </tp-yt-paper-tooltip>
# </div>
# <ytd-badge-supported-renderer class="style-scope ytd-channel-name" disable-upgrade="" hidden="">
# </ytd-badge-supported-renderer>
# </ytd-channel-name>
# </div>
# <yt-formatted-string class="style-scope ytd-video-renderer" hidden="" id="description-text"><!--css-build:shady--></yt-formatted-string>
# <div class="metadata-snippet-container style-scope ytd-video-renderer">
# <a class="yt-simple-endpoint metadata-snippet-timestamp style-scope ytd-video-renderer" hidden="">
# <span class="style-scope ytd-video-renderer" id="time"></span>
# <yt-formatted-string class="metadata-snippet-text-navigation style-scope ytd-video-renderer"><span class="style-scope yt-formatted-string" dir="auto">Hi friends, today I am sharing 3 reasons why I left </span><span class="bold style-scope yt-formatted-string" dir="auto">data</span><span class="style-scope yt-formatted-string" dir="auto"> engineering. Let me know in comments if any of this resonated with you.</span></yt-formatted-string>
# </a>
# <yt-formatted-string class="metadata-snippet-text style-scope ytd-video-renderer"><span class="style-scope yt-formatted-string" dir="auto">Hi friends, today I am sharing 3 reasons why I left </span><span class="bold style-scope yt-formatted-string" dir="auto">data</span><span class="style-scope yt-formatted-string" dir="auto"> engineering. Let me know in comments if any of this resonated with you.</span></yt-formatted-string>
# <tp-yt-paper-tooltip class="style-scope ytd-video-renderer" role="tooltip" tabindex="-1"><!--css-build:shady--><div class="hidden style-scope tp-yt-paper-tooltip" id="tooltip">
#   From the video description
# </div>
# </tp-yt-paper-tooltip>
# </div>
# <dom-repeat class="style-scope ytd-video-renderer"><template is="dom-repeat"></template></dom-repeat>
# <ytd-badge-supported-renderer class="style-scope ytd-video-renderer" disable-upgrade="" hidden="" id="badges">
# </ytd-badge-supported-renderer>
# <div class="style-scope ytd-video-renderer" id="expandable-metadata"></div>
# <div class="style-scope ytd-video-renderer" id="buttons"></div>
# </div>
# </div>
# <div class="style-scope ytd-video-renderer" id="dismissed"></div>
# </ytd-video-renderer><ytd-video-renderer class="style-scope ytd-vertical-list-renderer" inline-title-icon="" lockup="true" prominent-thumb-style="DEFAULT" use-prominent-thumbs=""><!--css-build:shady--><div class="style-scope ytd-video-renderer" id="dismissible">
# <ytd-thumbnail class="style-scope ytd-video-renderer" use-hovered-property=""><!--css-build:shady--><a aria-hidden="true" class="yt-simple-endpoint inline-block style-scope ytd-thumbnail" href="/watch?v=34r9OwjysDM" id="thumbnail" rel="null" tabindex="-1">
# <yt-img-shadow class="style-scope ytd-thumbnail no-transition empty" ftl-eligible="" style="background-color: transparent;"><!--css-build:shady--><img alt="" class="style-scope yt-img-shadow" id="img" width="360"/></yt-img-shadow>
# <div class="style-scope ytd-thumbnail" id="overlays"></div>
# <div class="style-scope ytd-thumbnail" id="mouseover-overlay"></div>
# <div class="style-scope ytd-thumbnail" id="hover-overlays"></div>
# </a>
# </ytd-thumbnail>
# <div class="text-wrapper style-scope ytd-video-renderer">
# <div class="style-scope ytd-video-renderer" id="meta">
# <div class="style-scope ytd-video-renderer" id="title-wrapper">
# <h3 class="title-and-badge style-scope ytd-video-renderer">
# <ytd-badge-supported-renderer class="style-scope ytd-video-renderer" disable-upgrade="" hidden="">
# </ytd-badge-supported-renderer>
# <a aria-label="My Data Science Journey with Non-Tech Background by Sundas Khalid 3 months ago 15 minutes 243,270 views" class="yt-simple-endpoint style-scope ytd-video-renderer" href="/watch?v=34r9OwjysDM" id="video-title" title="My Data Science Journey with Non-Tech Background">
# <yt-icon class="style-scope ytd-video-renderer" hidden="" id="inline-title-icon"><!--css-build:shady--></yt-icon>
# <yt-formatted-string aria-label="My Data Science Journey with Non-Tech Background by Sundas Khalid 3 months ago 15 minutes 243,270 views" class="style-scope ytd-video-renderer">My Data Science Journey with Non-Tech Background</yt-formatted-string>
# </a>
# </h3>
# <div class="style-scope ytd-video-renderer" id="menu"><ytd-menu-renderer class="style-scope ytd-video-renderer" menu-active=""><!--css-build:shady--><div class="top-level-buttons style-scope ytd-menu-renderer" id="top-level-buttons-computed"></div>
# <yt-icon-button class="dropdown-trigger style-scope ytd-menu-renderer" id="button" touch-feedback=""><!--css-build:shady--><button aria-label="Action menu" class="style-scope yt-icon-button" id="button">
# <yt-icon class="style-scope ytd-menu-renderer"><svg class="style-scope yt-icon" focusable="false" preserveaspectratio="xMidYMid meet" style="pointer-events: none; display: block; width: 100%; height: 100%;" viewbox="0 0 24 24"><g class="style-scope yt-icon"><path class="style-scope yt-icon" d="M12,16.5c0.83,0,1.5,0.67,1.5,1.5s-0.67,1.5-1.5,1.5s-1.5-0.67-1.5-1.5S11.17,16.5,12,16.5z M10.5,12 c0,0.83,0.67,1.5,1.5,1.5s1.5-0.67,1.5-1.5s-0.67-1.5-1.5-1.5S10.5,11.17,10.5,12z M10.5,6c0,0.83,0.67,1.5,1.5,1.5 s1.5-0.67,1.5-1.5S12.83,4.5,12,4.5S10.5,5.17,10.5,6z"></path></g></svg><!--css-build:shady--></yt-icon>
# </button><yt-interaction class="circular style-scope yt-icon-button" id="interaction"><!--css-build:shady--><div class="stroke style-scope yt-interaction"></div><div class="fill style-scope yt-interaction"></div></yt-interaction></yt-icon-button>
# </ytd-menu-renderer></div>
# </div>
# <ytd-video-meta-block class="style-scope ytd-video-renderer byline-separated"><!--css-build:shady-->
# <div class="style-scope ytd-video-meta-block" id="metadata">
# <div class="style-scope ytd-video-meta-block" hidden="" id="byline-container">
# <ytd-channel-name class="style-scope ytd-video-meta-block" id="channel-name"><!--css-build:shady--><div class="style-scope ytd-channel-name" id="container">
# <div class="style-scope ytd-channel-name" id="text-container">
# <yt-formatted-string class="style-scope ytd-channel-name complex-string" ellipsis-truncate="" has-link-only_="" id="text" title=""><a class="yt-simple-endpoint style-scope yt-formatted-string" dir="auto" href="/channel/UCteRPiisgIoHtMgqHegpWAQ" spellcheck="false">Sundas Khalid</a></yt-formatted-string>
# </div>
# <tp-yt-paper-tooltip class="style-scope ytd-channel-name" fit-to-visible-bounds="" role="tooltip" tabindex="-1"><!--css-build:shady--><div class="hidden style-scope tp-yt-paper-tooltip" id="tooltip">
#
#     Sundas Khalid
#
# </div>
# </tp-yt-paper-tooltip>
# </div>
# <ytd-badge-supported-renderer class="style-scope ytd-channel-name" disable-upgrade="" hidden="">
# </ytd-badge-supported-renderer>
# </ytd-channel-name>
# <div class="style-scope ytd-video-meta-block" id="separator">•</div>
# </div>
# <div class="style-scope ytd-video-meta-block" id="metadata-line">
# <span class="style-scope ytd-video-meta-block">243K views</span>
# <span class="style-scope ytd-video-meta-block">3 months ago</span>
# <dom-repeat class="style-scope ytd-video-meta-block" strip-whitespace=""><template is="dom-repeat"></template></dom-repeat>
# </div>
# </div>
# <div class="style-scope ytd-video-meta-block" id="additional-metadata-line">
# <dom-repeat class="style-scope ytd-video-meta-block"><template is="dom-repeat"></template></dom-repeat>
# </div>
# </ytd-video-meta-block>
# </div>
# <div class="style-scope ytd-video-renderer" id="channel-info">
# <a aria-label="Go to channel" class="style-scope ytd-video-renderer" href="/channel/UCteRPiisgIoHtMgqHegpWAQ">
# <yt-img-shadow class="style-scope ytd-video-renderer no-transition empty" style="background-color: transparent;" width="24"><!--css-build:shady--><img alt="" class="style-scope yt-img-shadow" id="img" width="24"/></yt-img-shadow>
# </a>
# <ytd-channel-name class="long-byline style-scope ytd-video-renderer" id="channel-name" wrap-text="true"><!--css-build:shady--><div class="style-scope ytd-channel-name" id="container">
# <div class="style-scope ytd-channel-name" id="text-container">
# <yt-formatted-string class="style-scope ytd-channel-name" has-link-only_="" id="text" title=""><a class="yt-simple-endpoint style-scope yt-formatted-string" dir="auto" href="/channel/UCteRPiisgIoHtMgqHegpWAQ" spellcheck="false">Sundas Khalid</a></yt-formatted-string>
# </div>
# <tp-yt-paper-tooltip class="style-scope ytd-channel-name" fit-to-visible-bounds="" role="tooltip" tabindex="-1"><!--css-build:shady--><div class="hidden style-scope tp-yt-paper-tooltip" id="tooltip">
#
#     Sundas Khalid
#
# </div>
# </tp-yt-paper-tooltip>
# </div>
# <ytd-badge-supported-renderer class="style-scope ytd-channel-name" disable-upgrade="" hidden="">
# </ytd-badge-supported-renderer>
# </ytd-channel-name>
# </div>
# <yt-formatted-string class="style-scope ytd-video-renderer" hidden="" id="description-text"><!--css-build:shady--></yt-formatted-string>
# <div class="metadata-snippet-container style-scope ytd-video-renderer">
# <a class="yt-simple-endpoint metadata-snippet-timestamp style-scope ytd-video-renderer" hidden="">
# <span class="style-scope ytd-video-renderer" id="time"></span>
# <yt-formatted-string class="metadata-snippet-text-navigation style-scope ytd-video-renderer"><span class="style-scope yt-formatted-string" dir="auto">Hi friends, I am sharing my transition to </span><span class="bold style-scope yt-formatted-string" dir="auto">data science</span><span class="style-scope yt-formatted-string" dir="auto"> with non-tech background as well as my experience working at Amazon and ...</span></yt-formatted-string>
# </a>
# <yt-formatted-string class="metadata-snippet-text style-scope ytd-video-renderer"><span class="style-scope yt-formatted-string" dir="auto">Hi friends, I am sharing my transition to </span><span class="bold style-scope yt-formatted-string" dir="auto">data science</span><span class="style-scope yt-formatted-string" dir="auto"> with non-tech background as well as my experience working at Amazon and ...</span></yt-formatted-string>
# <tp-yt-paper-tooltip class="style-scope ytd-video-renderer" role="tooltip" tabindex="-1"><!--css-build:shady--><div class="hidden style-scope tp-yt-paper-tooltip" id="tooltip">
#   From the video description
# </div>
# </tp-yt-paper-tooltip>
# </div>
# <dom-repeat class="style-scope ytd-video-renderer"><template is="dom-repeat"></template></dom-repeat>
# <ytd-badge-supported-renderer class="style-scope ytd-video-renderer" disable-upgrade="" hidden="" id="badges">
# </ytd-badge-supported-renderer>
# <div class="style-scope ytd-video-renderer" id="expandable-metadata"></div>
# <div class="style-scope ytd-video-renderer" id="buttons"></div>
# </div>
# </div>
# <div class="style-scope ytd-video-renderer" id="dismissed"></div>
# </ytd-video-renderer></div>
# <div class="style-scope ytd-vertical-list-renderer" id="more">
# <yt-formatted-string aria-label="+6 more" class="style-scope ytd-vertical-list-renderer"><span class="style-scope yt-formatted-string" dir="auto">+</span><span class="style-scope yt-formatted-string" dir="auto">6</span><span class="style-scope yt-formatted-string" dir="auto"> more</span></yt-formatted-string>
# </div>
# <div class="style-scope ytd-vertical-list-renderer" hidden="" id="all">
# <a class="yt-simple-endpoint style-scope ytd-vertical-list-renderer" href$="[[computeHref_(data.expandedStateButtonEndpoint]]">
# <yt-formatted-string class="style-scope ytd-vertical-list-renderer"><!--css-build:shady--></yt-formatted-string>
# </a>
# </div>
# </ytd-vertical-list-renderer></div>
# </div>
# <div class="style-scope ytd-shelf-renderer" id="dismissed"></div>
# </ytd-shelf-renderer></div>
# <div class="style-scope ytd-item-section-renderer" id="continuations"></div>
# </ytd-item-section-renderer><ytd-continuation-item-renderer class="style-scope ytd-section-list-renderer"><!--css-build:shady--><div class="style-scope ytd-continuation-item-renderer" id="ghost-cards"></div>
# <tp-yt-paper-spinner aria-hidden="true" class="style-scope ytd-continuation-item-renderer" id="spinner"><!--css-build:shady--><div class="style-scope tp-yt-paper-spinner" id="spinnerContainer"><div class="spinner-layer layer-1 style-scope tp-yt-paper-spinner"><div class="circle-clipper left style-scope tp-yt-paper-spinner"><div class="circle style-scope tp-yt-paper-spinner"></div></div><div class="circle-clipper right style-scope tp-yt-paper-spinner"><div class="circle style-scope tp-yt-paper-spinner"></div></div></div><div class="spinner-layer layer-2 style-scope tp-yt-paper-spinner"><div class="circle-clipper left style-scope tp-yt-paper-spinner"><div class="circle style-scope tp-yt-paper-spinner"></div></div><div class="circle-clipper right style-scope tp-yt-paper-spinner"><div class="circle style-scope tp-yt-paper-spinner"></div></div></div><div class="spinner-layer layer-3 style-scope tp-yt-paper-spinner"><div class="circle-clipper left style-scope tp-yt-paper-spinner"><div class="circle style-scope tp-yt-paper-spinner"></div></div><div class="circle-clipper right style-scope tp-yt-paper-spinner"><div class="circle style-scope tp-yt-paper-spinner"></div></div></div><div class="spinner-layer layer-4 style-scope tp-yt-paper-spinner"><div class="circle-clipper left style-scope tp-yt-paper-spinner"><div class="circle style-scope tp-yt-paper-spinner"></div></div><div class="circle-clipper right style-scope tp-yt-paper-spinner"><div class="circle style-scope tp-yt-paper-spinner"></div></div></div></div></tp-yt-paper-spinner>
# <div class="style-scope ytd-continuation-item-renderer" hidden="" id="button"></div>
# </ytd-continuation-item-renderer></div>

# %%
contents_div = soup.find('div', id='contents')

for title in contents_div.find_all('a', id='video-title'):
    print(title.text.strip())
# Out:
# Data Science In 5 Minutes | Data Science For Beginners | What Is Data Science? | Simplilearn
# Learn Data Science Tutorial - Full Course for Beginners
# What REALLY is Data Science? Told by a Data Scientist
# Is Data Science Dying?
# How I Would Learn Data Science (If I Had to Start Over)
# Главные профессии в ИИ - Data Science, Data Analyst, Data Engineer | Академия ИИ
# Why you should not be a data scientist
# A Day in The Life of a Google Data Scientist (Analytics)
# يعني إيه علم البيانات Data Science | #إسأل_مصطفى
# Data science - كل ما تود معرفته عن مجال علم البيانات
# تعريف علم البيانات | What is Data Science?
# علم البيانات - data science
# Data Scientist vs Data Analyst (funny!)
# MUST WATCH Before Choosing Data Analyst As Your Career!
# Why I Left Data Engineering for Data Science
# My Data Science Journey with Non-Tech Background

# %% [markdown]
# > **QUESTION**: We only got about 20 video titles -- surely there are more videos about data science.  What do you think is happening?

# %% [markdown]
# ### Interacting with Pages
#
# We can also interact with pages using Selenium.  For example, we can
# - click
# - type in input cells
# - scroll
# - drag and drop, etc.
#
# If we want more data science video titles, we need to scroll down to the bottom of the screen for more videos to populate.

# %%
for i in range(5):
    #Scroll
    driver.execute_script(
        "window.scrollTo(0, document.documentElement.scrollHeight);" #Alternatively, document.body.scrollHeight
    )
    
    #Wait for page to load
    time.sleep(1)

# %%
soup = BeautifulSoup(driver.page_source, 'html.parser')

# %%
contents_div = soup.find('div', id='contents')

len(contents_div.find_all('a', id='video-title'))

# %% [markdown]
# Awesome!  Now we have several more videos to analyze and we could continue scrolling if we wanted even more.
#
# What if we want to perform a new search for machine learning?

# %%
search_box = driver.find_element_by_xpath("//input[@id='search']")

#clear the current search
search_box.clear()

#input new search
search_box.send_keys("machine learning")

#hit enter
search_box.send_keys(Keys.RETURN)  

time.sleep(1)

# %% [markdown]
# And can we filter to short videos (< 4 minutes) only?

# %%
filter_button = driver.find_element_by_xpath(
    '//a[contains(@class, "ytd-toggle-button")]'
)
filter_button.click()

# %%
short_link = driver.find_element_by_xpath(
    '//div[contains(@title, "Search for Short")]'
)
short_link.click()

# %% [markdown]
# Now we can either parse the page source with Beautiful Soup like before or pull text directly.
#
# For example, the title of the first short ML video (that isn't an ad!) can be found with:

# %%
first_title = driver.find_element_by_xpath("//a[@id='video-title']")
first_title.text

# %%
first_author = driver.find_element_by_xpath(
    "//ytd-video-renderer//ytd-channel-name//a"
)
first_author.text

# %% [markdown]
# #### Notes
#
# - Check [here](https://www.w3schools.com/xml/xpath_syntax.asp) for additonal help writing xpath selectors.
#
# - To select multiple elements, just switch to `driver.find_elements_by_xpath(...)`, which will return a list of matching elements.
#
# - You can also access elements by id, name, etc.  Check [the docs](https://selenium-python.readthedocs.io/locating-elements.html) for more options.

# %% [markdown]
# Finally, when you are finished with the driver, be sure to close it.

# %%
driver.close()

# %% [markdown]
# ## Example 2 - Open Table  _(Optional)_
#
# Let's try one more example: gathering information from Open Table about restaurants with available reservation slots.

# %%
driver = webdriver.Chrome(chromedriver)
driver.get('http://www.opentable.com/')
time.sleep(1)  #pause to be sure page has loaded

# %% [markdown]
# Inspecting this page, we see the **name** of the drop down for picking the number of people is `Select_1`. Let's set the reservation for 4 people:

# %%
people_dropdown = driver.find_element_by_xpath('//select[@aria-label="Party size selector"]')
people_dropdown.send_keys("4 people")
time.sleep(1)

# %% [markdown]
# Now select the reservation date: 3 days from now.

# %%
from datetime import datetime, timedelta

# %%
today = datetime.today()
today_truncated = datetime(today.year, today.month, today.day)
res_date = (today + timedelta(days=3)).strftime('%a, %b %d, %Y')
res_date

# %%
#Expand the calendar
date_picker = driver.find_element_by_xpath('//div[@aria-label="Date selector"]')
date_picker.click()
time.sleep(1)

# %%
#Select the date three days from now
date_element = driver.find_element_by_xpath(f'//div[@aria-label="{res_date}"]')
date_element.click()
time.sleep(1)

# %% [markdown]
# Set our reservation time for 8 PM.

# %%
time_dropdown = driver.find_element_by_xpath('//select[@aria-label="Time selector"]')
time_dropdown.send_keys("8:00 PM")
time.sleep(1)

# %% [markdown]
# And search!

# %%
search_button = driver.find_element_by_xpath("//*[contains(text(), 'Let’s go')]")
search_button.click()
time.sleep(1)

# %% [markdown]
# On this new page we find a long list of restaurants with available reservations for 4 people at roughly our desired day/time.  At this point we could grab the HTML (`driver.page_source`) and parse with BeautifulSoup.

# %%
soup = BeautifulSoup(driver.page_source)

# %%
for rest in soup.find_all('div', class_='rest-row-header')[:20]:
    print(rest.find('a').text)

# %% [markdown]
# Or we could click into an individual restaurant to learn more.

# %%
first_rest = driver.find_element_by_xpath('//div[@class="rest-row-header"]//a')
first_rest.click()

# %%
rest_soup = BeautifulSoup(driver.page_source)

print(rest_soup.title.text)

# %% [markdown]
# > **QUESTION**:  Why doesn't the title of this page match up with this individual restaurant?

# %%
#Switch windows!
driver.switch_to.window(driver.window_handles[1])

# %%
rest_soup = BeautifulSoup(driver.page_source)

print(rest_soup.title.text)

# %% [markdown]
# As usual when working with Selenium, make sure to close your browser.  Since we have two windows up, we use `driver.quit()` to close the entire browser session.

# %%
driver.quit()
